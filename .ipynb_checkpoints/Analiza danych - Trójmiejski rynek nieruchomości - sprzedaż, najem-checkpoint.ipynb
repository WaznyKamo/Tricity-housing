# %% [markdown]
# # Analiza danych z użyciem języka programowania Python

# %% [markdown]
# ### Komentarz wstępny
#
# * Zbiory danych nie są równoliczne - występuje 4421 ofert sprzedaży oraz 458 ofert najmu. Będą one natomiast przede wszystkim analizowane samodzielnie.
# * Występują dzielnice z ilością ofert poniżej 3, co utrudnia wnioskowanie na temat ich charakterystyk. Autorzy zdecydowali się nie usuwać tych rekordów pomimo niskiej liczności z uwagi na ich właściwą reprezentację na rynku sprzedaży i najmu (i.e., ich niższa liczba odzwierciedla niską rzeczywistą podaż).

# %%
# Zaimportowanie niezbędnych bibliotek

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Zmiana formatu wyświetlania danych typu float

pd.options.display.float_format = '{:,.2f}'.format

# %%
# Utworzenie ramki danych

df = pd.read_csv("data_cleaned_for_real.csv")

# %%
df
# Out:
#          Cena  Miasto    Dzielnica  Pokoje  Pow. całkowita  Rok budowy  \
# 0      518569  Gdynia       Cisowa       2           40.72        2025
# 1      518569  Gdynia       Cisowa       2           40.72        2025
# 2      518569  Gdynia       Cisowa       2           40.72        2025
# 3      518569  Gdynia       Cisowa       2           40.72        2025
# 4      518569  Gdynia       Cisowa       2           40.72        2025
# ...       ...     ...          ...     ...             ...         ...
# 4874  1500000   Sopot  Górny Sopot       4           73.27        1915
# 4875  2337500   Sopot  Górny Sopot       5          106.25        2023
# 4876  1649000   Sopot  Górny Sopot       5           93.10        1950
# 4877  1500000   Sopot  Dolny Sopot       3           80.00        1900
# 4878  1880000   Sopot  Dolny Sopot       3           81.00        1910
#
#       Piętro  Liczba pięter  Balkon   Cena/m2  Sprzedaż  Najem  \
# 0          1              4       0 12,735.00         1      0
# 1          1              4       0 12,735.00         1      0
# 2          1              4       0 12,735.00         1      0
# 3          1              4       0 12,735.00         1      0
# 4          1              4       0 12,735.00         1      0
# ...      ...            ...     ...       ...       ...    ...
# 4874       2              2       0 20,472.23         1      0
# 4875       3              3       0 22,000.00         1      0
# 4876       2              3       1 17,712.14         1      0
# 4877       3              3       1 18,750.00         1      0
# 4878       1              2       0 23,209.88         1      0
#
#       Rynek pierwotny
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 4874                0
# 4875                1
# 4876                0
# 4877                0
# 4878                0
#
# [4879 rows x 13 columns]

# %%
# Podstawowe informacje o ramce danych

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4879 entries, 0 to 4878
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Cena             4879 non-null   int64
#  1   Miasto           4879 non-null   object
#  2   Dzielnica        4879 non-null   object
#  3   Pokoje           4879 non-null   int64
#  4   Pow. całkowita   4879 non-null   float64
#  5   Rok budowy       4879 non-null   int64
#  6   Piętro           4879 non-null   int64
#  7   Liczba pięter    4879 non-null   int64
#  8   Balkon           4879 non-null   int64
#  9   Cena/m2          4879 non-null   float64
#  10  Sprzedaż         4879 non-null   int64
#  11  Najem            4879 non-null   int64
#  12  Rynek pierwotny  4879 non-null   int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 495.6+ KB

# %%
df[df["Sprzedaż"] == 1].count()
# Out:
# Cena               4421
# Miasto             4421
# Dzielnica          4421
# Pokoje             4421
# Pow. całkowita     4421
# Rok budowy         4421
# Piętro             4421
# Liczba pięter      4421
# Balkon             4421
# Cena/m2            4421
# Sprzedaż           4421
# Najem              4421
# Rynek pierwotny    4421
# dtype: int64

# %%
df[df["Najem"] == 1].count()
# Out:
# Cena               458
# Miasto             458
# Dzielnica          458
# Pokoje             458
# Pow. całkowita     458
# Rok budowy         458
# Piętro             458
# Liczba pięter      458
# Balkon             458
# Cena/m2            458
# Sprzedaż           458
# Najem              458
# Rynek pierwotny    458
# dtype: int64

# %%
# Podzielenie ramki danych na dwa podzbiory: sell (sprzedaż) i rent (najem)

sell = df[df["Sprzedaż"] == 1]
sell
# Out:
#          Cena  Miasto    Dzielnica  Pokoje  Pow. całkowita  Rok budowy  \
# 0      518569  Gdynia       Cisowa       2           40.72        2025
# 1      518569  Gdynia       Cisowa       2           40.72        2025
# 2      518569  Gdynia       Cisowa       2           40.72        2025
# 3      518569  Gdynia       Cisowa       2           40.72        2025
# 4      518569  Gdynia       Cisowa       2           40.72        2025
# ...       ...     ...          ...     ...             ...         ...
# 4874  1500000   Sopot  Górny Sopot       4           73.27        1915
# 4875  2337500   Sopot  Górny Sopot       5          106.25        2023
# 4876  1649000   Sopot  Górny Sopot       5           93.10        1950
# 4877  1500000   Sopot  Dolny Sopot       3           80.00        1900
# 4878  1880000   Sopot  Dolny Sopot       3           81.00        1910
#
#       Piętro  Liczba pięter  Balkon   Cena/m2  Sprzedaż  Najem  \
# 0          1              4       0 12,735.00         1      0
# 1          1              4       0 12,735.00         1      0
# 2          1              4       0 12,735.00         1      0
# 3          1              4       0 12,735.00         1      0
# 4          1              4       0 12,735.00         1      0
# ...      ...            ...     ...       ...       ...    ...
# 4874       2              2       0 20,472.23         1      0
# 4875       3              3       0 22,000.00         1      0
# 4876       2              3       1 17,712.14         1      0
# 4877       3              3       1 18,750.00         1      0
# 4878       1              2       0 23,209.88         1      0
#
#       Rynek pierwotny
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 4874                0
# 4875                1
# 4876                0
# 4877                0
# 4878                0
#
# [4421 rows x 13 columns]

# %%
rent = df[df["Najem"] == 1]
rent
# Out:
#        Cena  Miasto             Dzielnica  Pokoje  Pow. całkowita  Rok budowy  \
# 1102   2500  Gdynia         Działki Leśne       2           44.00        1960
# 1103  21600  Gdynia           Śródmieście       3           84.00        2020
# 1104   2100  Gdynia  Witomino Radjostacja       2           49.00        1998
# 1105   7000  Gdynia                Orłowo       2           76.08        2011
# 1106   6500  Gdynia           Śródmieście       2           50.00        2020
# ...     ...     ...                   ...     ...             ...         ...
# 4545    250   Sopot           Dolny Sopot       3           66.26        1975
# 4546   2900   Sopot               Wyścigi       2           38.00        2019
# 4547  12000   Sopot           Dolny Sopot       5          132.00        2014
# 4548   6000   Sopot           Dolny Sopot       3           90.00        1970
# 4549   2200   Sopot        Kamienny Potok       2           36.00        1975
#
#       Piętro  Liczba pięter  Balkon  Cena/m2  Sprzedaż  Najem  Rynek pierwotny
# 1102       1              5       1    56.82         0      1                0
# 1103       1              4       1   257.14         0      1                0
# 1104       4              4       0    42.86         0      1                0
# 1105       5              5       1    92.01         0      1                0
# 1106       1             17       1   130.00         0      1                0
# ...      ...            ...     ...      ...       ...    ...              ...
# 4545       4              4       1     3.77         0      1                0
# 4546       2              2       1    76.32         0      1                0
# 4547       3              3       0    90.91         0      1                0
# 4548       1              3       1    66.67         0      1                0
# 4549       7             10       0    61.11         0      1                0
#
# [458 rows x 13 columns]

# %% [markdown]
# # Rynek sprzedaży

# %%
# Usunięcie zbędnych kolumn

sell = sell.drop(columns=['Sprzedaż', 'Najem'])

# %%
# Podstawowe statystyki danych sprzedażowych

sell.describe()
# Out:
#               Cena   Pokoje  Pow. całkowita  Rok budowy   Piętro  \
# count     4,421.00 4,421.00        4,421.00    4,421.00 4,421.00
# mean  1,001,553.58     2.73           62.83    2,001.21     2.49
# std     705,917.24     1.01           27.38       34.25     2.40
# min     169,000.00     1.00           15.61    1,700.00     1.00
# 25%     593,840.00     2.00           44.08    1,985.00     1.00
# 50%     777,281.00     3.00           57.10    2,020.00     2.00
# 75%   1,152,725.00     3.00           74.00    2,024.00     3.00
# max   9,725,700.00    13.00          288.80    2,026.00    27.00
#
#        Liczba pięter   Balkon   Cena/m2  Rynek pierwotny
# count       4,421.00 4,421.00  4,421.00         4,421.00
# mean            4.92     0.56 15,744.48             0.33
# std             3.49     0.50  6,215.30             0.47
# min             1.00     0.00  4,002.06             0.00
# 25%             3.00     0.00 11,231.37             0.00
# 50%             4.00     1.00 14,111.11             0.00
# 75%             5.00     1.00 18,732.14             1.00
# max            37.00     1.00 57,894.74             1.00

# %%
grouped_s = sell.groupby("Miasto").mean()
grouped_s
# Out:
# C:\Users\almak\AppData\Local\Temp\ipykernel_28208\3867037762.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_s = sell.groupby("Miasto").mean()
#                Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  \
# Miasto
# Gdańsk   910,690.42    2.65           59.24    2,005.98    2.49
# Gdynia   995,211.68    2.86           67.58    2,000.76    2.43
# Sopot  1,851,433.15    3.00           79.60    1,959.23    2.59
#
#         Liczba pięter  Balkon   Cena/m2  Rynek pierwotny
# Miasto
# Gdańsk           4.83    0.55 15,443.06             0.36
# Gdynia           5.54    0.59 14,553.71             0.33
# Sopot            3.65    0.50 22,493.88             0.13

# %%
# Średnie wartości dla trzech miast oraz dodanie liczby ofert

grouped_s["Liczba ofert"] = sell.groupby(["Miasto"])["Miasto"].count()
grouped_s
# Out:
#                Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  \
# Miasto
# Gdańsk   910,690.42    2.65           59.24    2,005.98    2.49
# Gdynia   995,211.68    2.86           67.58    2,000.76    2.43
# Sopot  1,851,433.15    3.00           79.60    1,959.23    2.59
#
#         Liczba pięter  Balkon   Cena/m2  Rynek pierwotny  Liczba ofert
# Miasto
# Gdańsk           4.83    0.55 15,443.06             0.36          2991
# Gdynia           5.54    0.59 14,553.71             0.33          1102
# Sopot            3.65    0.50 22,493.88             0.13           328

# %%
# Liczba ofert na rynku wtórnym i pierwotnym

sell.groupby(["Rynek pierwotny"])["Rynek pierwotny"].count()
# Out:
# Rynek pierwotny
# 0    2943
# 1    1478
# Name: Rynek pierwotny, dtype: int64

# %%
2943/(2943+1478)
# Out:
# 0.6656864962678127

# %% [markdown]
# Na rynku sprzedaży przeważają oferty z rynku wtórnego (67%).

# %%
# Liczba ofert sprzedaży w danej dzielnicy - dolnych 20 dzielnic

# %%
sell.groupby(["Dzielnica"])['Dzielnica'].count().sort_values(ascending=False).tail(20)
# Out:
# Dzielnica
# Nowy Port                      22
# Kamienny Potok                 19
# Karlikowo                      18
# Leszczynki                     15
# Matarnia                       15
# Świemirowo                     14
# Karwiny                        13
# Pustki Cisowskie - Demptowo    12
# VII Dwór                       10
# Przeróbka                       9
# Przylesie                       7
# Wyścigi                         6
# Strzyża                         6
# Witomino Radjostacja            5
# Brętowo                         5
# Brodwino                        3
# Olszynka                        3
# Rudniki                         2
# Szadółki                        1
# Młyniska                        1
# Name: Dzielnica, dtype: int64

# %%
# Sprawdzenie istotnych korelacji dla rynku sprzedaży

sell.corr()
# Out:
# C:\Users\almak\AppData\Local\Temp\ipykernel_28208\3440587283.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sell.corr()
#                  Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  \
# Cena             1.00    0.46            0.70       -0.09    0.04
# Pokoje           0.46    1.00            0.77       -0.09    0.01
# Pow. całkowita   0.70    0.77            1.00       -0.15    0.01
# Rok budowy      -0.09   -0.09           -0.15        1.00   -0.03
# Piętro           0.04    0.01            0.01       -0.03    1.00
# Liczba pięter   -0.01   -0.02           -0.04        0.08    0.58
# Balkon           0.06    0.12            0.08        0.13    0.03
# Cena/m2          0.70   -0.06            0.07        0.03    0.06
# Rynek pierwotny -0.12   -0.08           -0.11        0.47   -0.05
#
#                  Liczba pięter  Balkon  Cena/m2  Rynek pierwotny
# Cena                     -0.01    0.06     0.70            -0.12
# Pokoje                   -0.02    0.12    -0.06            -0.08
# Pow. całkowita           -0.04    0.08     0.07            -0.11
# Rok budowy                0.08    0.13     0.03             0.47
# Piętro                    0.58    0.03     0.06            -0.05
# Liczba pięter             1.00   -0.01     0.04             0.06
# Balkon                   -0.01    1.00     0.04            -0.15
# Cena/m2                   0.04    0.04     1.00            -0.11
# Rynek pierwotny           0.06   -0.15    -0.11             1.00

# %% [markdown]
# ### Istotne korelacje:
#
# * Między ceną a powierzchnią całkowitą (0.7), liczbą pokoi (0.46)
# * Między pokojami a powierzchnią całkowitą (0.77)
# * Rokiem budowy a rynkiem pierwotnym/wtórnym (0.47)
#
# Co ciekawe, brak istotnej zależności między posiadaniem balkonu a ceną/ceną za metr kwadratowy. Co więcej, nie ma korelacji między ceną/ceną za metr kwadratowy a rokiem budowy.

# %%
# Najdroższe i najtańsze lokalizacje w Trójmieście pod względem ceny za metr kwadratowy

dzielnice_s = sell.groupby(["Miasto", "Dzielnica"]).mean().sort_values("Cena/m2", ascending=False)
dzielnice_s
# Out:
#                                            Cena  Pokoje  Pow. całkowita  \
# Miasto Dzielnica
# Gdańsk Jelitkowo                   2,449,949.98    2.90           68.28
# Gdynia Orłowo                      2,314,493.00    3.24           86.64
# Sopot  Dolny Sopot                 2,306,145.52    3.23           90.83
#        Świemirowo                  1,455,493.36    2.64           67.95
#        Wyścigi                     1,538,166.67    2.83           74.80
# ...                                         ...     ...             ...
# Gdynia Pustki Cisowskie - Demptowo   664,781.67    3.17           67.14
#        Obłuże                        657,960.00    3.56           72.10
# Gdańsk Kowale                        449,277.53    2.36           47.26
#        Rudniki                       334,450.00    2.00           37.05
#        Kokoszki                      682,577.78    3.09           74.12
#
#                                     Rok budowy  Piętro  Liczba pięter  Balkon  \
# Miasto Dzielnica
# Gdańsk Jelitkowo                      2,010.40    2.17           4.38    0.88
# Gdynia Orłowo                         2,011.89    1.22           2.35    0.81
# Sopot  Dolny Sopot                    1,940.31    2.43           3.04    0.43
#        Świemirowo                     2,012.29    2.43           3.00    0.64
#        Wyścigi                        1,993.50    1.67           5.50    0.67
# ...                                        ...     ...            ...     ...
# Gdynia Pustki Cisowskie - Demptowo    2,000.33    1.67           2.83    0.83
#        Obłuże                         1,987.28    2.20           4.52    0.88
# Gdańsk Kowale                         2,024.95    2.45           5.00    0.00
#        Rudniki                        1,979.00    1.00           4.00    0.00
#        Kokoszki                       2,015.31    2.53           4.64    0.60
#
#                                      Cena/m2  Rynek pierwotny
# Miasto Dzielnica
# Gdańsk Jelitkowo                   35,795.84             0.00
# Gdynia Orłowo                      25,993.17             0.16
# Sopot  Dolny Sopot                 24,971.24             0.04
#        Świemirowo                  21,453.15             0.86
#        Wyścigi                     21,266.07             0.00
# ...                                      ...              ...
# Gdynia Pustki Cisowskie - Demptowo 10,058.79             0.25
#        Obłuże                       9,861.05             0.04
# Gdańsk Kowale                       9,552.59             1.00
#        Rudniki                      9,547.98             0.00
#        Kokoszki                     9,516.64             0.27
#
# [62 rows x 9 columns]

# %%
dzielnice_s["Liczba ofert"] = sell.groupby(["Miasto", "Dzielnica"])["Dzielnica"].count()
dzielnice_s
# Out:
#                                            Cena  Pokoje  Pow. całkowita  \
# Miasto Dzielnica
# Gdańsk Jelitkowo                   2,449,949.98    2.90           68.28
# Gdynia Orłowo                      2,314,493.00    3.24           86.64
# Sopot  Dolny Sopot                 2,306,145.52    3.23           90.83
#        Świemirowo                  1,455,493.36    2.64           67.95
#        Wyścigi                     1,538,166.67    2.83           74.80
# ...                                         ...     ...             ...
# Gdynia Pustki Cisowskie - Demptowo   664,781.67    3.17           67.14
#        Obłuże                        657,960.00    3.56           72.10
# Gdańsk Kowale                        449,277.53    2.36           47.26
#        Rudniki                       334,450.00    2.00           37.05
#        Kokoszki                      682,577.78    3.09           74.12
#
#                                     Rok budowy  Piętro  Liczba pięter  Balkon  \
# Miasto Dzielnica
# Gdańsk Jelitkowo                      2,010.40    2.17           4.38    0.88
# Gdynia Orłowo                         2,011.89    1.22           2.35    0.81
# Sopot  Dolny Sopot                    1,940.31    2.43           3.04    0.43
#        Świemirowo                     2,012.29    2.43           3.00    0.64
#        Wyścigi                        1,993.50    1.67           5.50    0.67
# ...                                        ...     ...            ...     ...
# Gdynia Pustki Cisowskie - Demptowo    2,000.33    1.67           2.83    0.83
#        Obłuże                         1,987.28    2.20           4.52    0.88
# Gdańsk Kowale                         2,024.95    2.45           5.00    0.00
#        Rudniki                        1,979.00    1.00           4.00    0.00
#        Kokoszki                       2,015.31    2.53           4.64    0.60
#
#                                      Cena/m2  Rynek pierwotny  Liczba ofert
# Miasto Dzielnica
# Gdańsk Jelitkowo                   35,795.84             0.00            40
# Gdynia Orłowo                      25,993.17             0.16            37
# Sopot  Dolny Sopot                 24,971.24             0.04           170
#        Świemirowo                  21,453.15             0.86            14
#        Wyścigi                     21,266.07             0.00             6
# ...                                      ...              ...           ...
# Gdynia Pustki Cisowskie - Demptowo 10,058.79             0.25            12
#        Obłuże                       9,861.05             0.04            25
# Gdańsk Kowale                       9,552.59             1.00            87
#        Rudniki                      9,547.98             0.00             2
#        Kokoszki                     9,516.64             0.27            45
#
# [62 rows x 10 columns]

# %% [markdown]
# Najwyższą cenę za metr kwadratowy można zaobserwować w nadmorskich dzielnicach: w Jelitkowie, w Orłowie, w Dolnym Sopocie, Świemirowie (Sopot) oraz Sopocie Wyścigach. Najniższa cena występuje na obrzeżach miast (Kokoszki, Rudniki, Kowale, Obłuże, Pustki Cisowskie).

# %% [markdown]
# # Wizualizacja danych rynku sprzedaży

# %%
numeric = ["Cena"]
sell[numeric].boxplot(figsize=(7,7))
plt.title("Wykresy boxplot dla ceny mieszkań:")
plt.ylabel("Wartości:")
plt.show()

# %%
numeric = ["Cena/m2"]
sell[numeric].boxplot(figsize=(7,7))
plt.title("Wykresy Boxplot dla danych numerycznych:")
plt.ylabel("Wartości:")
plt.show()

# %%
numeric = ["Pow. całkowita"]
sell[numeric].boxplot(figsize=(7,7))
plt.title("Wykresy Boxplot dla danych numerycznych:")
plt.ylabel("Wartości:")
plt.show()

# %%
sell['Rok budowy'].hist()
plt.show()

# %%
sell['Pokoje'].hist()
plt.show()

# %%
plt.hist(sell[sell['Miasto'] == 'Gdańsk']['Cena/m2'], bins=10, alpha=0.9, color='pink', label='Gdańsk') 
plt.hist(sell[sell['Miasto'] == 'Gdynia']['Cena/m2'], bins=10, alpha=0.9, color='orange', label='Gdynia') 
plt.hist(sell[sell['Miasto'] == 'Sopot']['Cena/m2'], bins=10, alpha=0.9, color='yellow', label='Sopot') 

plt.title('Histogramy cen sprzedaży za metr kwadratowy w Gdańsku, Gdyni i Sopocie')
plt.xlabel('Cena za metr kwadratowy')
plt.ylabel('Liczba ofert')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Najwięcej ofert sprzedaży pochodzi z Gdańska, następnie z Gdyni i wreszcie z Sopotu. Wykres dla Sopotu jest najbardziej płaski - odzwierciedla to większą wariancję cenową w Sopocie niż w pozostałych dwóch miastach.

# %%
fig, ax = plt.subplots()
sell['Dzielnica'].value_counts().plot(ax=ax, kind='bar')
plt.title('Histogram liczby ofert sprzedaży w danej dzielnicy')
plt.rcParams["figure.figsize"] = (7,5)
plt.show()

# %% [markdown]
# # Rynek najmu

# %%
rent = rent.drop(columns=['Sprzedaż', 'Najem'])

# %%
rent.groupby("Miasto").mean()
# Out:
# C:\Users\almak\AppData\Local\Temp\ipykernel_28208\274963737.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rent.groupby("Miasto").mean()
#            Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  Liczba pięter  \
# Miasto
# Gdańsk 3,388.22    2.15           49.46    2,007.21    2.93           5.14
# Gdynia 3,482.87    2.34           55.94    1,998.14    2.35           4.76
# Sopot  4,494.23    2.73           64.06    1,984.08    3.04           4.00
#
#         Balkon  Cena/m2  Rynek pierwotny
# Miasto
# Gdańsk    0.67    69.31             0.01
# Gdynia    0.64    62.07             0.01
# Sopot     0.77    70.35             0.00

# %%
grouped_r = rent.groupby("Miasto").mean()
grouped_r
# Out:
# C:\Users\almak\AppData\Local\Temp\ipykernel_28208\149857847.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_r = rent.groupby("Miasto").mean()
#            Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  Liczba pięter  \
# Miasto
# Gdańsk 3,388.22    2.15           49.46    2,007.21    2.93           5.14
# Gdynia 3,482.87    2.34           55.94    1,998.14    2.35           4.76
# Sopot  4,494.23    2.73           64.06    1,984.08    3.04           4.00
#
#         Balkon  Cena/m2  Rynek pierwotny
# Miasto
# Gdańsk    0.67    69.31             0.01
# Gdynia    0.64    62.07             0.01
# Sopot     0.77    70.35             0.00

# %%
# Średnie wartości dla trzech miast oraz dodanie liczby ofert

grouped_r["Liczba ofert"] = rent.groupby(["Miasto"])["Miasto"].count()
grouped_r
# Out:
#            Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  Liczba pięter  \
# Miasto
# Gdańsk 3,388.22    2.15           49.46    2,007.21    2.93           5.14
# Gdynia 3,482.87    2.34           55.94    1,998.14    2.35           4.76
# Sopot  4,494.23    2.73           64.06    1,984.08    3.04           4.00
#
#         Balkon  Cena/m2  Rynek pierwotny  Liczba ofert
# Miasto
# Gdańsk    0.67    69.31             0.01           314
# Gdynia    0.64    62.07             0.01           118
# Sopot     0.77    70.35             0.00            26

# %%
rent.groupby(["Rynek pierwotny"])["Rynek pierwotny"].count()
# Out:
# Rynek pierwotny
# 0    455
# 1      3
# Name: Rynek pierwotny, dtype: int64

# %% [markdown]
# W porównaniu do ofert sprzedaży, na rynku najmu zdecydowanie dominują oferty z rynku wtórnego (455 vs 3 na rynku pierwotnym).

# %%
# Liczba ofert najmu w danej dzielnicy - dolne 25

rent.groupby(["Dzielnica"])['Dzielnica'].count().sort_values(ascending=False).tail(25)
# Out:
# Dzielnica
# Witomino Leśniczówka         3
# Karlikowo                    3
# Kamienna Góra                3
# Osowa                        3
# Dąbrowa                      3
# Wyścigi                      3
# Strzyża                      2
# Szadółki                     2
# Suchanino                    2
# Witomino Radjostacja         2
# Oksywie                      2
# Brodwino                     2
# Obłuże                       2
# Matarnia                     2
# Krakowiec-Górki Zachodnie    2
# Kokoszki                     2
# Kamienny Potok               2
# Cisowa                       2
# Chwarzno-Wiczlino            2
# Żabianka                     2
# Rudniki                      1
# Chylonia                     1
# Zakoniczyn                   1
# Brętowo                      1
# Świemirowo                   1
# Name: Dzielnica, dtype: int64

# %%
# Sprawdzenie istotnych korelacji dla rynku najmu

rent.corr()
# Out:
# C:\Users\almak\AppData\Local\Temp\ipykernel_28208\250782620.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rent.corr()
#                  Cena  Pokoje  Pow. całkowita  Rok budowy  Piętro  \
# Cena             1.00    0.52            0.68        0.07    0.22
# Pokoje           0.52    1.00            0.82       -0.07    0.09
# Pow. całkowita   0.68    0.82            1.00       -0.09    0.08
# Rok budowy       0.07   -0.07           -0.09        1.00    0.08
# Piętro           0.22    0.09            0.08        0.08    1.00
# Liczba pięter    0.14    0.02           -0.01        0.09    0.71
# Balkon           0.07    0.11            0.07        0.31    0.11
# Cena/m2          0.63   -0.11           -0.07        0.17    0.16
# Rynek pierwotny -0.04   -0.02           -0.06        0.02    0.01
#
#                  Liczba pięter  Balkon  Cena/m2  Rynek pierwotny
# Cena                      0.14    0.07     0.63            -0.04
# Pokoje                    0.02    0.11    -0.11            -0.02
# Pow. całkowita           -0.01    0.07    -0.07            -0.06
# Rok budowy                0.09    0.31     0.17             0.02
# Piętro                    0.71    0.11     0.16             0.01
# Liczba pięter             1.00    0.10     0.17            -0.02
# Balkon                    0.10    1.00    -0.03            -0.12
# Cena/m2                   0.17   -0.03     1.00             0.05
# Rynek pierwotny          -0.02   -0.12     0.05             1.00

# %% [markdown]
# ### Istotne korelacje:
#
# * Między ceną a powierzchnią całkowitą (0.68), liczbą pokoi (0.52)
# * Między pokojami a powierzchnią całkowitą (0.82)
# * Między rokiem budowy a balkonem (0.31)
#
# Występuje słaba korelacja między piętrem a ceną (0.22) oraz między ceną za metr kwadratowy a rokiem budowy (0.17).
#
# Co ciekawe, brak istotnej zależności między posiadaniem balkonu a ceną/ceną za metr kwadratowy. Co więcej, nie ma korelacji między ceną/ceną za metr kwadratowy a rokiem budowy.
#
# Zgodnie z oczekiwaniami, istnieje tu nieco słabsza zależność między ceną a ceną za metr kwadratowy (0.63) niż w przypadku rynku sprzedaży (0.7).

# %%
# Najdroższe i najtańsze dzielnice (Cena)

dzielnice_r = rent.groupby(["Miasto", "Dzielnica"]).mean().sort_values("Cena/m2", ascending=False)

# %%
dzielnice_r["Liczba ofert"] = rent.groupby(["Miasto", "Dzielnica"])["Dzielnica"].count()
dzielnice_r
# Out:
#                                          Cena  Pokoje  Pow. całkowita  \
# Miasto Dzielnica
# Sopot  Górny Sopot                   6,025.00    3.00           59.15
# Gdynia Śródmieście                   5,696.88    2.38           62.27
# Gdańsk Zaspa                         2,885.81    1.69           34.37
#        Rudniki                       2,600.00    2.00           30.00
#        Śródmieście                   4,462.71    2.27           54.05
#        Matarnia                      2,350.00    1.50           30.00
# Sopot  Karlikowo                     4,300.00    2.33           53.33
#        Wyścigi                       3,766.67    2.33           49.50
# Gdynia Kamienna Góra                 4,800.00    2.67           67.67
# Gdańsk Brzeźno                       2,518.00    1.40           34.75
#        Przymorze                     3,363.75    2.04           47.47
#        Szadółki                      2,450.00    1.50           34.30
#        Letnica                       3,130.00    2.10           45.11
# Gdynia Orłowo                        3,842.50    2.00           56.38
# Gdańsk Żabianka                      4,200.00    2.50           54.00
#        Oliwa                         4,030.77    2.54           57.52
#        Strzyża                       3,800.00    2.50           53.84
#        Wrzeszcz                      3,617.48    2.26           55.64
# Gdynia Działki Leśne                 3,957.14    2.29           59.16
# Gdańsk Kokoszki                      2,550.00    1.50           38.52
# Gdynia Wzgórze Świętego Maksymiliana 3,657.14    2.43           61.14
# Gdańsk Krakowiec-Górki Zachodnie     2,550.00    2.00           39.40
#        Siedlce                       3,100.00    2.20           48.02
# Sopot  Dolny Sopot                   4,922.73    2.91           78.04
# Gdańsk Suchanino                     4,650.00    3.00           70.50
#        Piecki-Migowo                 2,846.00    2.13           46.78
# Gdynia Cisowa                        3,425.00    2.50           52.50
# Gdańsk Ujeścisko-Łostowice           2,584.26    2.00           44.02
# Sopot  Świemirowo                    2,800.00    2.00           47.00
# Gdańsk Jasień                        2,795.12    2.10           48.40
# Gdynia Mały Kack                     2,837.50    2.00           49.52
# Sopot  Kamienny Potok                2,600.00    2.00           46.00
# Gdynia Chwarzno-Wiczlino             2,350.00    2.00           41.41
# Gdańsk Orunia                        2,380.69    2.00           43.26
# Gdynia Obłuże                        2,650.00    2.50           47.86
# Gdańsk Chełm                         2,325.00    2.10           43.31
#        Aniołki                       3,540.00    2.80           68.56
# Gdynia Grabówek                      2,228.57    1.86           43.25
#        Witomino Leśniczówka          2,333.33    2.33           44.67
#        Karwiny                       2,750.00    2.50           53.85
#        Pogórze                       2,766.67    2.67           52.21
# Gdańsk Jelitkowo                     3,416.67    2.50           61.29
# Sopot  Brodwino                      3,200.00    3.50           61.50
# Gdynia Redłowo                       2,399.80    1.80           45.51
#        Oksywie                       3,750.00    3.50           73.00
# Gdańsk Osowa                         2,600.00    2.00           51.73
# Gdynia Leszczynki                    2,022.50    2.00           41.75
#        Wielki Kack                   3,000.00    2.60           68.24
#        Dąbrowa                       2,500.00    2.67           55.03
# Gdańsk Zakoniczyn                    2,300.00    2.00           50.00
# Gdynia Witomino Radjostacja          2,050.00    2.00           45.77
#        Chylonia                      2,000.00    3.00           46.50
# Gdańsk Brętowo                       2,510.00    3.00           60.50
# Gdynia Pustki Cisowskie - Demptowo   2,937.50    3.25           73.42
#
#                                       Rok budowy  Piętro  Liczba pięter  \
# Miasto Dzielnica
# Sopot  Górny Sopot                      1,972.50    1.75           2.75
# Gdynia Śródmieście                      2,001.25    3.62           7.56
# Gdańsk Zaspa                            2,007.00    3.00           6.19
#        Rudniki                          2,023.00    1.00           4.00
#        Śródmieście                      2,004.14    3.16           4.91
#        Matarnia                         2,023.00    1.00           2.00
# Sopot  Karlikowo                        2,005.67    2.33           3.00
#        Wyścigi                          2,016.00    2.33           2.33
# Gdynia Kamienna Góra                    1,943.00    1.67           2.67
# Gdańsk Brzeźno                          1,979.60    2.40           4.00
#        Przymorze                        2,004.62    5.08           7.96
#        Szadółki                         2,023.00    3.50           4.00
#        Letnica                          2,021.60    6.70          11.80
# Gdynia Orłowo                           2,005.38    1.88           3.12
# Gdańsk Żabianka                         1,993.50    5.50           7.00
#        Oliwa                            1,987.85    2.15           3.77
#        Strzyża                          1,985.00    2.50           4.00
#        Wrzeszcz                         2,001.42    2.77           5.42
# Gdynia Działki Leśne                    1,998.24    1.81           3.71
# Gdańsk Kokoszki                         2,021.00    2.00           4.00
# Gdynia Wzgórze Świętego Maksymiliana    1,999.14    2.14           7.57
# Gdańsk Krakowiec-Górki Zachodnie        1,994.00    1.00           4.00
#        Siedlce                          2,000.40    3.00           6.20
# Sopot  Dolny Sopot                      1,971.64    2.73           3.82
# Gdańsk Suchanino                        1,995.00    2.00           7.00
#        Piecki-Migowo                    2,008.47    3.87           6.40
# Gdynia Cisowa                           1,979.50    2.50           7.50
# Gdańsk Ujeścisko-Łostowice              2,017.96    1.96           3.57
# Sopot  Świemirowo                       2,006.00    1.00           2.00
# Gdańsk Jasień                           2,016.83    2.10           4.15
# Gdynia Mały Kack                        2,011.00    1.00           3.25
# Sopot  Kamienny Potok                   1,994.50    5.00           6.50
# Gdynia Chwarzno-Wiczlino                2,017.00    1.50           3.00
# Gdańsk Orunia                           2,009.69    2.08           4.08
# Gdynia Obłuże                           1,999.00    6.00           7.50
# Gdańsk Chełm                            2,014.40    2.10           3.70
#        Aniołki                          2,003.60    1.20           3.60
# Gdynia Grabówek                         1,976.43    2.57           4.43
#        Witomino Leśniczówka             1,993.67    2.67           6.33
#        Karwiny                          1,997.50    2.25           5.25
#        Pogórze                          2,013.00    3.00           4.00
# Gdańsk Jelitkowo                        2,013.67    2.00           3.00
# Sopot  Brodwino                         1,974.00    8.50          10.00
# Gdynia Redłowo                          1,994.60    2.40           6.20
#        Oksywie                          2,016.50    2.00           3.00
# Gdańsk Osowa                            2,011.00    2.00           3.33
# Gdynia Leszczynki                       1,989.00    1.75           3.00
#        Wielki Kack                      2,007.80    1.60           2.60
#        Dąbrowa                          1,995.00    2.67           4.00
# Gdańsk Zakoniczyn                       2,008.00    1.00           4.00
# Gdynia Witomino Radjostacja             1,981.50    3.00           4.00
#        Chylonia                         1,971.00    4.00          10.00
# Gdańsk Brętowo                          1,988.00    2.00           4.00
# Gdynia Pustki Cisowskie - Demptowo      2,002.25    1.75           4.00
#
#                                       Balkon  Cena/m2  Rynek pierwotny  \
# Miasto Dzielnica
# Sopot  Górny Sopot                      0.50    97.43             0.00
# Gdynia Śródmieście                      0.56    88.64             0.00
# Gdańsk Zaspa                            0.31    87.26             0.06
#        Rudniki                          0.00    86.67             0.00
#        Śródmieście                      0.60    81.35             0.00
#        Matarnia                         0.00    78.62             0.00
# Sopot  Karlikowo                        1.00    78.42             0.00
#        Wyścigi                          1.00    76.12             0.00
# Gdynia Kamienna Góra                    0.00    74.92             0.00
# Gdańsk Brzeźno                          0.60    72.93             0.00
#        Przymorze                        0.54    72.87             0.00
#        Szadółki                         0.50    72.03             0.50
#        Letnica                          0.90    71.69             0.00
# Gdynia Orłowo                           0.88    71.24             0.00
# Gdańsk Żabianka                         0.50    70.93             0.00
#        Oliwa                            0.54    70.00             0.00
#        Strzyża                          1.00    69.73             0.00
#        Wrzeszcz                         0.71    67.52             0.00
# Gdynia Działki Leśne                    0.76    66.45             0.00
# Gdańsk Kokoszki                         0.50    65.81             0.00
# Gdynia Wzgórze Świętego Maksymiliana    0.43    65.27             0.00
# Gdańsk Krakowiec-Górki Zachodnie        0.00    64.56             0.00
#        Siedlce                          0.60    64.38             0.00
# Sopot  Dolny Sopot                      0.73    63.37             0.00
# Gdańsk Suchanino                        1.00    63.23             0.00
#        Piecki-Migowo                    0.93    62.23             0.00
# Gdynia Cisowa                           1.00    62.21             0.00
# Gdańsk Ujeścisko-Łostowice              0.57    61.19             0.00
# Sopot  Świemirowo                       1.00    59.57             0.00
# Gdańsk Jasień                           0.85    59.51             0.00
# Gdynia Mały Kack                        0.88    58.18             0.00
# Sopot  Kamienny Potok                   0.50    57.34             0.00
# Gdynia Chwarzno-Wiczlino                0.50    57.04             0.00
# Gdańsk Orunia                           0.92    56.05             0.00
# Gdynia Obłuże                           1.00    55.81             0.00
# Gdańsk Chełm                            0.80    55.56             0.00
#        Aniołki                          0.60    54.09             0.00
# Gdynia Grabówek                         0.29    53.47             0.00
#        Witomino Leśniczówka             0.67    53.28             0.00
#        Karwiny                          1.00    52.80             0.00
#        Pogórze                          0.78    52.71             0.00
# Gdańsk Jelitkowo                        1.00    52.22             0.00
# Sopot  Brodwino                         1.00    52.21             0.00
# Gdynia Redłowo                          0.60    51.90             0.00
#        Oksywie                          0.50    51.88             0.00
# Gdańsk Osowa                            1.00    51.72             0.00
# Gdynia Leszczynki                       0.50    48.54             0.00
#        Wielki Kack                      0.40    46.44             0.00
#        Dąbrowa                          0.33    46.35             0.33
# Gdańsk Zakoniczyn                       1.00    46.00             0.00
# Gdynia Witomino Radjostacja             0.50    44.94             0.00
#        Chylonia                         0.00    43.01             0.00
# Gdańsk Brętowo                          1.00    41.49             0.00
# Gdynia Pustki Cisowskie - Demptowo      1.00    40.56             0.00
#
#                                       Liczba ofert
# Miasto Dzielnica
# Sopot  Górny Sopot                               4
# Gdynia Śródmieście                              16
# Gdańsk Zaspa                                    16
#        Rudniki                                   1
#        Śródmieście                              77
#        Matarnia                                  2
# Sopot  Karlikowo                                 3
#        Wyścigi                                   3
# Gdynia Kamienna Góra                             3
# Gdańsk Brzeźno                                   5
#        Przymorze                                24
#        Szadółki                                  2
#        Letnica                                  10
# Gdynia Orłowo                                    8
# Gdańsk Żabianka                                  2
#        Oliwa                                    13
#        Strzyża                                   2
#        Wrzeszcz                                 31
# Gdynia Działki Leśne                            21
# Gdańsk Kokoszki                                  2
# Gdynia Wzgórze Świętego Maksymiliana             7
# Gdańsk Krakowiec-Górki Zachodnie                 2
#        Siedlce                                   5
# Sopot  Dolny Sopot                              11
# Gdańsk Suchanino                                 2
#        Piecki-Migowo                            15
# Gdynia Cisowa                                    2
# Gdańsk Ujeścisko-Łostowice                      23
# Sopot  Świemirowo                                1
# Gdańsk Jasień                                   41
# Gdynia Mały Kack                                 8
# Sopot  Kamienny Potok                            2
# Gdynia Chwarzno-Wiczlino                         2
# Gdańsk Orunia                                   13
# Gdynia Obłuże                                    2
# Gdańsk Chełm                                    10
#        Aniołki                                   5
# Gdynia Grabówek                                  7
#        Witomino Leśniczówka                      3
#        Karwiny                                   4
#        Pogórze                                   9
# Gdańsk Jelitkowo                                 6
# Sopot  Brodwino                                  2
# Gdynia Redłowo                                   5
#        Oksywie                                   2
# Gdańsk Osowa                                     3
# Gdynia Leszczynki                                4
#        Wielki Kack                               5
#        Dąbrowa                                   3
# Gdańsk Zakoniczyn                                1
# Gdynia Witomino Radjostacja                      2
#        Chylonia                                  1
# Gdańsk Brętowo                                   1
# Gdynia Pustki Cisowskie - Demptowo               4

# %% [markdown]
# Najdroższe mieszkania pod względem ceny za metr kwadratowy (pomijając pojedyncze oferty) występują w Górnym Sopocie, w Gdyni Śródmieście, na Zaspie. Najtańsze mieszkania znajdują się w Pustkach Cisowskich, na Witominie, Zakoniczynie.

# %% [markdown]
# # Wizualizacja danych rynku najmu

# %%
plt.hist(rent[rent['Miasto'] == 'Gdańsk']['Cena'], bins=15, alpha=0.9, color='pink', label='Gdańsk') 
plt.hist(rent[rent['Miasto'] == 'Gdynia']['Cena'], bins=15, alpha=0.9, color='orange', label='Gdynia') 
plt.hist(rent[rent['Miasto'] == 'Sopot']['Cena'], bins=15, alpha=0.9, color='yellow', label='Sopot') 

plt.title('Histogramy cen najmu w Gdańsku, Gdyni i Sopocie')
plt.xlabel('Cena')
plt.ylabel('Liczba ofert')
plt.legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots()
rent['Dzielnica'].value_counts().plot(ax=ax, kind='bar')
plt.title('Histogram liczby ofert najmu w danej dzielnicy')
plt.rcParams["figure.figsize"] = (10,7)
plt.show()

# %% [markdown]
# # !
#
# <font color="red">To do:
#
# * dodać więcej wykresów
# * opis wykresów
# * najem i sprzedaż - histogram liczby ofert per dzielnica - Śródmieście liczone jako Gdynia i Gdańsk
