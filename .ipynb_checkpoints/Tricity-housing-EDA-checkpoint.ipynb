# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
gdansk = pd.read_csv(r"data\flat-sell_Gdansk.csv", sep='|')
gdynia = pd.read_csv(r"data\flat-sell_Gdynia.csv", sep='|')
sopot = pd.read_csv(r"data\flat-sell_Sopot.csv", sep='|')

# %%
gdansk.head()
# Out:
#                                                Nazwa          Cena    Miasto  \
# 0   Luksusowe mieszkanie/3 pokoje/Zajezdnia Wrzeszcz  1 399 000 zł  Gdańsk,
# 1               Mieszkanie 2 pokoje Gdańsk Przymorze    539 000 zł  Gdańsk,
# 2  Mieszkanie ENERGOOSZCZĘDNE 90m² z ogrodem, bez...    360 185 zł  Gdańsk,
# 3                                 Opis nieruchomości    457 835 zł  Gdańsk,
# 4  8700/m2 1,5km tramwaj_ Hale_ komórki_ balkon_R...    580 000 zł  Gdańsk,
#
#           Dzielnica       Pokoje Pow. całkowita Piętro  Liczba pięter  \
# 0  Wrzeszcz Dolny,    • 3 pokoje       61,21 m²    1/4            4.0
# 1       Przymorze,    • 2 pokoje          46 m²   8/10           10.0
# 2       Łostowice,    • 4 pokoje          90 m²    NaN            NaN
# 3       Łostowice,    • 2 pokoje       40,66 m²    NaN            NaN
# 4            Jasień   • 4 pokoje       59,80 m²    3/4            4.0
#
#    Liczba sypialni Balkon      Rynek   Rodzaj umowy  Rok budowy Data dodania  \
# 0              2.0    Tak     Wtórny  Na wyłączność      2021.0   22.04.2024
# 1              NaN    Tak     Wtórny  Na wyłączność      1973.0   03.04.2024
# 2              NaN    NaN  Pierwotny            NaN      2025.0   21.03.2024
# 3              NaN    NaN  Pierwotny            NaN      2025.0   19.02.2024
# 4              NaN    Tak  Pierwotny            NaN      2023.0   06.03.2024
#
#   Aktualizacja    Numer ogłoszenia Liczba odsłon  Liczba Punktów Podbić  \
# 0   22.04.2024      morizon-467068             1                     25
# 1   18.04.2024    morizon-WH105140         1 188                    301
# 2   17.04.2024  morizon-Mieszkanie         3 273                    250
# 3   22.04.2024    morizon-B2-B2.34            75                    211
# 4   15.04.2024        morizon-1042           183                    210
#
#    Liczba poziomów mieszkania Dostępne od        Typ budynku  \
# 0                         NaN         NaN                NaN
# 1                         1.0  05.04.2024           Falowiec
# 2                         2.0         NaN  Dom wielorodzinny
# 3                         NaN         NaN                NaN
# 4                         NaN         NaN               Blok
#
#   Materiał budowlany   Ogrzewanie           Inwestycja Stan nieruchomości  \
# 0                NaN          NaN                  NaN                NaN
# 1              Cegła  Co Miejskie                  NaN                NaN
# 2             Pustak          NaN  Domm 90M2 Z Ogrodem     Do wykończenia
# 3                NaN          NaN              Quercus                NaN
# 4       Wielka płyta     Miejskie                  NaN     Do wykończenia
#
#   Typ kuchni  Liczba łazienek łazienka razem z WC Taras Pow. ogródka  \
# 0        NaN              NaN                 NaN   NaN          NaN
# 1        NaN              NaN                 NaN   NaN          NaN
# 2      Aneks              2.0                 Tak   Tak       200 m²
# 3        NaN              NaN                 NaN   NaN          NaN
# 4        NaN              NaN                 NaN   NaN          NaN
#
#   Forma własności Stolarka okienna Pow. tarasu Pow. loggii Pow. balkonu  \
# 0             NaN              NaN         NaN         NaN          NaN
# 1             NaN              NaN         NaN         NaN          NaN
# 2        Własność              NaN         NaN         NaN          NaN
# 3             NaN              NaN         NaN         NaN          NaN
# 4        Własność              PCV         NaN         NaN          NaN
#
#   Stan budynku Wysokość wnętrza Pow. łazienki Pow. użytkowa  Dodatkowe koszty  \
# 0          NaN              NaN           NaN           NaN               NaN
# 1          NaN              NaN           NaN           NaN               NaN
# 2          NaN              NaN           NaN           NaN               NaN
# 3          NaN              NaN           NaN           NaN               NaN
# 4          NaN              NaN           NaN           NaN               NaN
#
#   Cena do negocjacji Typ nieruchomości Typ domu Lokalizacja garażu  \
# 0                NaN               NaN      NaN                NaN
# 1                NaN               NaN      NaN                NaN
# 2                NaN               NaN      NaN                NaN
# 3                NaN               NaN      NaN                NaN
# 4                NaN               NaN      NaN                NaN
#
#   Pow. działki
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
sell_data = pd.concat([gdansk, gdynia, sopot], ignore_index=True)

# %%
sell_data.tail()
# Out:
#                                                  Nazwa          Cena   Miasto  \
# 5144         Apartament z dużym ogrodem w sercu Sopotu  2 337 500 zł  Sopot,
# 5145  Inwestycyjne 3 mieszkania w jednym Sopot koło UG  1 649 000 zł  Sopot,
# 5146                            Dwa apaartamenty Sopot  2 290 000 zł  Sopot,
# 5147           Sopot Dolny, Sopot Górny, Sopot Wyścigi  1 500 000 zł  Sopot,
# 5148                                Mieszkanie - Sopot  1 880 000 zł  Sopot,
#
#                 Dzielnica       Pokoje Pow. całkowita Piętro  Liczba pięter  \
# 5144              Górny,     • 5 pokoi      106,25 m²    NaN            3.0
# 5145     Artura Grottgera    • 5 pokoi       93,10 m²    2/3            3.0
# 5146  Władysława Łokietka   • 3 pokoje          74 m²    NaN            3.0
# 5147              Dolny,    • 3 pokoje          80 m²    NaN            1.0
# 5148              Dolny,    • 3 pokoje          81 m²    1/2            2.0
#
#       Liczba sypialni Balkon      Rynek   Rodzaj umowy  Rok budowy  \
# 5144              4.0    NaN  Pierwotny            NaN      2023.0
# 5145              NaN    Tak     Wtórny  Na wyłączność      1950.0
# 5146              NaN    NaN     Wtórny            NaN         NaN
# 5147              NaN    Tak     Wtórny            NaN      1900.0
# 5148              NaN    Nie     Wtórny            NaN      1910.0
#
#      Data dodania Aktualizacja  Numer ogłoszenia Liczba odsłon  \
# 5144   07.08.2023   30.11.2023  morizon-TC550387           307
# 5145   12.01.2022   14.05.2023    morizon-980811         2 657
# 5146   09.11.2023   04.02.2024  morizon-DJ495680           186
# 5147   01.12.2023   16.04.2024    morizon-SE0000           610
# 5148   21.11.2023   02.02.2024    morizon-HL0813           238
#
#       Liczba Punktów Podbić  Liczba poziomów mieszkania Dostępne od  \
# 5144                      0                         1.0         NaN
# 5145                      0                         NaN         NaN
# 5146                      0                         1.0  09.11.2023
# 5147                      0                         1.0         NaN
# 5148                      0                         1.0         NaN
#
#           Typ budynku Materiał budowlany   Ogrzewanie Inwestycja  \
# 5144  Apartamentowiec            Silikat  Co Miejskie        NaN
# 5145              NaN                NaN          NaN        NaN
# 5146  Apartamentowiec             Pustak  Co Miejskie        NaN
# 5147        Kamienica              Cegła          NaN        NaN
# 5148        Kamienica                NaN       Gazowe        NaN
#
#      Stan nieruchomości Typ kuchni  Liczba łazienek łazienka razem z WC Taras  \
# 5144                NaN        NaN              NaN                 NaN   NaN
# 5145                NaN        NaN              NaN                 NaN   NaN
# 5146                NaN        NaN              NaN                 NaN   Tak
# 5147                NaN    Otwarta              1.0                 Nie   Tak
# 5148       Bardzo dobry     Osobna              1.0                 Nie   Nie
#
#      Pow. ogródka Forma własności Stolarka okienna Pow. tarasu Pow. loggii  \
# 5144          NaN             NaN              NaN         NaN         NaN
# 5145          NaN             NaN              NaN         NaN         NaN
# 5146          NaN             NaN              NaN         NaN         NaN
# 5147       100 m²        Własność              NaN       10 m²        4 m²
# 5148          NaN        Własność              NaN         NaN         NaN
#
#      Pow. balkonu  Stan budynku Wysokość wnętrza Pow. łazienki Pow. użytkowa  \
# 5144          NaN           NaN              NaN           NaN           NaN
# 5145          NaN           NaN              NaN           NaN           NaN
# 5146          NaN           NaN              NaN           NaN           NaN
# 5147         4 m²  Bardzo dobry           300 cm          4 m²           NaN
# 5148          NaN  Bardzo dobry              NaN           NaN           NaN
#
#      Dodatkowe koszty Cena do negocjacji Typ nieruchomości Typ domu  \
# 5144              NaN                NaN               NaN      NaN
# 5145              NaN                NaN               NaN      NaN
# 5146              NaN                NaN               NaN      NaN
# 5147              NaN                Tak               NaN      NaN
# 5148              NaN                Tak               NaN      NaN
#
#      Lokalizacja garażu Pow. działki Kominek Urządzony ogród
# 5144                NaN          NaN     NaN             NaN
# 5145                NaN          NaN     NaN             NaN
# 5146                NaN          NaN     NaN             NaN
# 5147                NaN          NaN     NaN             NaN
# 5148                NaN          NaN     NaN             NaN

# %%
sell_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5149 entries, 0 to 5148
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nazwa                       5149 non-null   object
#  1   Cena                        5149 non-null   object
#  2   Miasto                      5149 non-null   object
#  3   Dzielnica                   5091 non-null   object
#  4   Pokoje                      5149 non-null   object
#  5   Pow. całkowita              5149 non-null   object
#  6   Piętro                      3807 non-null   object
#  7   Liczba pięter               4802 non-null   float64
#  8   Liczba sypialni             1782 non-null   float64
#  9   Balkon                      2680 non-null   object
#  10  Rynek                       5149 non-null   object
#  11  Rodzaj umowy                1490 non-null   object
#  12  Rok budowy                  4565 non-null   float64
#  13  Data dodania                5149 non-null   object
#  14  Aktualizacja                5149 non-null   object
#  15  Numer ogłoszenia            5149 non-null   object
#  16  Liczba odsłon               5149 non-null   object
#  17  Liczba Punktów Podbić       5149 non-null   int64
#  18  Liczba poziomów mieszkania  1018 non-null   float64
#  19  Dostępne od                 1108 non-null   object
#  20  Typ budynku                 3455 non-null   object
#  21  Materiał budowlany          1732 non-null   object
#  22  Ogrzewanie                  3373 non-null   object
#  23  Inwestycja                  618 non-null    object
#  24  Stan nieruchomości          709 non-null    object
#  25  Typ kuchni                  792 non-null    object
#  26  Liczba łazienek             618 non-null    float64
#  27  łazienka razem z WC         307 non-null    object
#  28  Taras                       1181 non-null   object
#  29  Pow. ogródka                29 non-null     object
#  30  Forma własności             795 non-null    object
#  31  Stolarka okienna            105 non-null    object
#  32  Pow. tarasu                 38 non-null     object
#  33  Pow. loggii                 33 non-null     object
#  34  Pow. balkonu                148 non-null    object
#  35  Stan budynku                314 non-null    object
#  36  Wysokość wnętrza            237 non-null    object
#  37  Pow. łazienki               78 non-null     object
#  38  Pow. użytkowa               231 non-null    object
#  39  Dodatkowe koszty            38 non-null     object
#  40  Cena do negocjacji          55 non-null     object
#  41  Typ nieruchomości           17 non-null     object
#  42  Typ domu                    8 non-null      object
#  43  Lokalizacja garażu          2 non-null      object
#  44  Pow. działki                1 non-null      object
#  45  Kominek                     1 non-null      object
#  46  Urządzony ogród             1 non-null      object
# dtypes: float64(5), int64(1), object(41)
# memory usage: 1.8+ MB

# %%
sell_data['Dzielnica'].unique()
# Out:
# array(['Wrzeszcz Dolny, ', 'Przymorze, ', 'Łostowice, ', 'Jasień',
#        'Siedlce, ', 'Stogi, ', 'Śródmieście, ', 'Letnica, ', 'Oliwa, ',
#        'Stare Miasto, ', 'Potokowa', 'Ujeścisko, ', 'Chełm, ',
#        'Orunia Górna-Gdańsk Południe, ', 'Wrzeszcz, ', 'Jasień, ',
#        'Ujeścisko-Łostowice, ', 'Jelitkowo, ', 'Zakoniczyn, ',
#        'Łostowice', 'Kiełpinek, ', 'Zaspa, ', 'Siedlce', 'Przymorze',
#        'Oliwa', 'Straganiarska', 'Orunia Górna, ', 'Wrzeszcz',
#        'Sobieszewo, ', 'Jelitkowo', 'Gdańsk, ', 'Piecki-Migowo, ',
#        'Toruńska', 'Osowa, ', 'Brzeźno, ', 'Aniołki, ', 'Dolne Miasto, ',
#        nan, 'Piecki-Migowo', 'Karczemki, ', 'Śródmieście',
#        'Orunia-Św. Wojciech-Lipce, ', 'Matarnia, ',
#        'Wyspa Sobieszewska, ', 'Orunia Południe, ', 'Myśliwska',
#        'Płocka  14', 'Brzeźno', 'Ujeścisko-Łostowice', 'Piastowska  90',
#        'Morena Piecki-Migowo', 'Orunia, ', 'Aleja Gen. Józefa Hallera',
#        'Aniołki', 'Morena, ', 'Suchanino, ', 'Kazimierza Wielkiego',
#        'Suchanino', 'Partyzantów', 'Strzyża, ', 'Vii Dwór, ',
#        'Nowy Port, ', 'Czerska', 'Eugeniusza Węgrzyna',
#        'Karczemki Kiełpińskie', 'Konstantego Bergiela', 'Przeróbka, ',
#        'Kokoszki, ', 'Wrzeszcz Górny, ', 'Morena Piecki-Migowo, ',
#        'Sobieszewo', 'Kazimierza Leskiego', 'Morena', 'Niedźwiednik, ',
#        'Żabianka, ', 'Damroki', 'Tysiąclecia', 'Hokejowa',
#        'Wincentego Witosa', 'Guderskiego', 'Olszynka', 'Główne Miasto, ',
#        'Nadmorski Dwór', 'Maćkowy, ', 'Kazimierza Pułaskiego',
#        'Sukiennicza', 'Stara Stocznia', 'Orunia-Św. Wojciech - Lipce, ',
#        'Pańska', 'Jaglana', 'Goplańska', 'Szafarnia', 'Chłopska',
#        'Lęborska 22', 'Zaspa-Rozstaje, ', 'Letnica', 'Dolne Miasto',
#        'Starodworska', 'Kowale, ', 'Turystyczna', 'Wawelska', 'Perłowa',
#        'Łąkowa', 'Goplańska  49', 'Gdańsk', 'Opacka 37', 'Brętowo, ',
#        'Ujeścisko - Łostowice', '3 Brygady Szczerbca', 'Zielona',
#        'Matarnia', 'Jaśkowa Dolina', 'Remusa', 'Legnicka',
#        'Adama Mickiewicza', 'Kartuska', 'Starówka', 'Cygańska Góra',
#        'Krzemowa', 'Starowiejska', 'Artura Grottgera', 'Angielska Grobla',
#        'Kołobrzeska', 'Ks. Jerzego Popiełuszki', 'Aleja Pawła Adamowicza',
#        'Zagrodowa', 'Budapesztańska', 'Sandomierska', 'Olimpijska',
#        'Niepołomicka', 'Ujeścisko Łostowice', 'Wzgórze Mickiewicza, ',
#        'Osowa', 'Rudniki, ', 'Świętokrzyska', 'Starogardzka',
#        'Jana Kochanowskiego', 'Kokoszki', 'Na Zboczu', 'Zaspa',
#        'Wielkopolska', 'Orunia Górna Gdańsk Południe', 'Grobla III',
#        'Władysława Jagiełły', 'Jabłoniowa', 'Zeusa', 'Kwiatowa', 'Chełm',
#        'Szeroka', 'Chełm Południe, ', 'Polanki', 'Sucha', 'Borkowska',
#        'Zakopiańska', 'Mostek', 'Orunia Południe', 'Długie Ogrody, ',
#        'Stokłosy', 'Juliusza Słowackiego', 'Szadółki, ', 'Potęgowska',
#        'Kryształowa', 'Sienna Grobla', 'Powstańców Warszawskich',
#        'Pastelowa', 'Kadmowa', 'Stare Przedmieście, ', 'Żabianka',
#        'Podwale Staromiejskie', 'Sobieszewko, ', 'Wilhelma Stryjewskiego',
#        'Ujeścisko', 'Śniadeckich', 'Jana z Kolna',
#        'Żabianka-Wejhera-Jelitkowo-Tysiąclecia, ', 'Wyzwolenia',
#        'Platynowa', 'Stolema', 'Siennicka', 'Migowo, ', 'Zakoniczyn',
#        'Ogarna', 'Wojciecha Kiedrowskiego', 'Olszynka, ', 'Storczykowa',
#        'Nowe Ujeścisko, ', 'Aleja Grunwaldzka', 'Piecki Migowo Morena',
#        'Wrzeszcz Górny', 'Chełm Południe',
#        'Ujeścisko Chełm I Gdańsk Południe', 'Obrońców Westerplatte',
#        'Stefana Batorego', 'Bolesława Krzywoustego', 'Nieborowska',
#        'Nowy Port', 'Sympatyczna', 'Szara', 'Orunia Górna',
#        'Prof. Jerzego Stankiewicza', 'Młyniska', 'Cisowa, ', 'Redłowo, ',
#        'Orłowo, ', 'Kamienna Góra, ', 'Pogórze', 'Chylonia, ',
#        'Mały Kack, ', 'Wzgórze Św. Maksymiliana, ', 'Działki Leśne, ',
#        'Oksywie, ', 'Pogórze, ', 'Pustki Cisowskie, ',
#        'Witomino-Leśniczówka, ', 'Grabówek, ', 'Wiczlino, ',
#        'Wzgórze Świętego Maksymiliana, ', 'Orląt Lwowskich', 'Zwycięstwa',
#        'Chwarzno-Wiczlino, ', 'Dąbrowa, ', 'Karwiny, ', 'Sucharskiego  4',
#        'Wielki Kack, ', 'Bernadowo, ', 'Redłowo', 'Wiczlino',
#        'Witomino Leśniczówka, ', 'Wielki Kack', 'Leszczynki, ',
#        'Fikakowo, ', 'Kolibki, ', 'Witomino, ', 'Obłuże, ', 'Gdynia, ',
#        'Węglowa', 'Wzgórze Św. Maksymiliana', 'Dąbrowa',
#        'Pustki Cisowskie   Demptowo, ', 'Karwiny', 'Żelazna',
#        'Kacze Buki, ', 'Żołnierzy I Armii Wojska Polskiego', 'Cisowa',
#        'Witomino-Leśniczówka', 'św. Piotra', 'Pogórze Górne, ',
#        'Chwarzno, ', 'Witomino-Radiostacja, ', 'Witomino', 'Mały Kack',
#        'Pustki Cisowskie-Demptowo, ', 'Chylonia', 'Morska', 'Oksywie',
#        'Olgierda', 'Rdestowa', 'Kamienna Góra', 'Orłowo',
#        '2 Morskiego Pułku Strzelców', 'Pustki Cisowskie-Demptowo',
#        'Demptowo, ', 'Stefana Żeromskiego', 'Kosakowo, ', 'Leśna Polana',
#        'Św. Piotra', 'Żeromskiego Stefana', 'Bieszczadzka',
#        'Chwarzno-Wiczlino', 'Swarzewska', 'kmdr. Staniewicza',
#        'Działki Leśne', 'Obłuże', 'Witomino Radiostacja, ', 'Grabówek',
#        'Babie Doły, ', 'Józefa Czyżewskiego', 'Dolny, ', 'Dolny Sopot, ',
#        'Górny, ', 'Gen. Kazimierza Pułaskiego', 'Jana Jerzego Haffnera',
#        'Świemirowo, ', 'Sopot, ', 'Daniela Chodowieckiego', 'Karlikowo, ',
#        'Kamienny Potok, ', 'Centrum, ', 'Brodwino, ',
#        'Ignacego Krasickiego', 'Bohaterów Monte Cassino',
#        'Armii Krajowej', 'Wyścigi, ', 'Mariana Mokwy', 'Podjazd',
#        'Smolna', '3 Maja', 'Przylesie, ', 'Karlikowska',
#        'Gen. Władysława Andersa', 'Grunwaldzka', 'Aleja Niepodległości',
#        '1 Maja', 'Dolny', 'Górny', 'Mikołaja Reja', 'Górny Sopot, ',
#        'Gen. Władysława Sikorskiego', 'Bitwy Pod Płowcami', '23 Marca',
#        'al. Niepodległości', 'Władysława Łokietka', 'Jacka Malczewskiego',
#        'Niepodległości', 'Dolny Sopot', 'Marii Skłodowskiej-Curie',
#        'Bolesława Chrobrego', 'Króla Jana Kazimierza', 'Karlikowo',
#        'Sopot Górny', 'Tadeusza Kościuszki', 'Fryderyka Chopina',
#        'Lipowa', 'gen. Władysława Sikorskiego', 'Stefana Okrzei', 'Polna'],
#       dtype=object)

# %%
sell_data['Piętro'].unique()
# Out:
# array(['1/4', '8/10', nan, '3/4', '3/3', '1/3', '6/17', '2/2', '2/5',
#        '1/2', '3/6', '4/6', '2/4', '4/4', '3/5', '2/17', '7/9', '10/17',
#        '7/12', '2/3', '14/17', '1/1', '5/6', '10/10', '7/7', '3/7',
#        '1/10', '3/10', '16/16', '2/10', '5/17', '11/11', '6/10', '7/10',
#        '1/5', '2/6', '13/17', '5/5', '2/7', '15/16', '1/9', '1/6',
#        '12/18', '4/10', '7/14', '17/17', '15/17', '6/16', '1/8', '4/16',
#        '4/8', '8/9', '13/19', '1/17', '9/17', '12/17', '4/5', '1/12',
#        '16/17', '9/10', '7/17', '12/16', '4/7', '4/12', '4/17', '2/12',
#        '6/11', '2/11', '1/11', '5/11', '5/7', '1/7', '6/9', '5/16', '9/9',
#        '9/16', '10/12', '3/8', '6/6', '8/17', '13/16', '9/11', '7/8',
#        '8/12', '15/18', '6/7', '5/12', '5/8', '2/8', '5/10', '12/12',
#        '8/8', '3/17', '10/11', '3/9', '6/8', '11/17', '17/18', '6/12',
#        '18/18', '1/13', '14/16', '11/16', '5/9', '1/16', '4/9', '2/16',
#        '4/18', '12/15', '4/11', '10/15', '1/15', '9/12', '7/18', '7/13',
#        '1/18', '7/16', '10/16', '5/18', '3/18', '2/18', '23/29', '8/16',
#        '11/14', '20/23', '13/23', '15/23', '23/23', '6/13', 'Suterena/3',
#        '2/28', '3/11', '21/37', '15/27', '15/32', 'Suterena/4', '3/14',
#        '3/13', '6/14', '6/18', '17/32', '27/27', '2/32', '3/16', '14/14',
#        '8/11', 'Suterena/2'], dtype=object)

# %%
sell_data['Liczba łazienek'].unique()
# Out:
# array([nan,  2.,  1.,  4.,  3.,  5.])

# %%
sell_data['Liczba poziomów mieszkania'].unique()
# Out:
# array([nan,  1.,  2.,  4.,  5.,  3.])

# %%
sell_data['Dostępne od'].unique()
# Out:
# array([nan, '05.04.2024', '15.04.2024', '14.03.2024', '01.04.2024',
#        '01.03.2024', '01.02.2024', '24.06.2024', '01.06.2024',
#        '30.12.2024', '10.04.2024', '19.03.2024', '01.09.2023',
#        '02.12.2024', '22.01.2024', '31.01.2024', '28.02.2024',
#        '27.04.2024', '09.04.2024', '18.01.2024', '10.01.2024',
#        '07.03.2024', '30.11.2023', '29.03.2023', '01.07.2024',
#        '12.03.2024', '12.12.2023', '30.06.2024', '29.02.2024',
#        '05.09.2023', '22.12.2023', '30.04.2024', '13.02.2024',
#        'Lipiec 2024', '31.05.2025', '04.03.2024', '09.01.2024',
#        'Od zaraz', '31.05.2024', 'Czerwiec 2024', '14.11.2023',
#        '26.02.2024', '30.01.2024', '16.12.2024', '02.02.2026',
#        '15.01.2026', '26.03.2024', '19.12.2023', '27.02.2024',
#        '31.03.2024', '01.08.2023', '15.02.2024', '07.02.2024',
#        '30.06.2025', '03.04.2024', '31.12.2024', '25.03.2024',
#        '13.04.2023', '28.09.2023', '08.01.2024', '14.11.2022',
#        '22.02.2024', '15.07.2023', '31.05.2023', '08.03.2024',
#        '01.01.2024', '14.12.2023', '06.04.2024', '20.04.2024',
#        '19.01.2024', '21.04.2024', '20.01.2024', '16.03.2024',
#        '01.11.2024', '22.03.2024', '11.04.2024', '01.05.2024',
#        '14.04.2024', '08.04.2024', '01.08.2024', '12.04.2024',
#        '07.04.2024', '13.04.2024', '04.04.2024', '29.01.2024',
#        '11.03.2024', '30.03.2025', '19.04.2024', '15.07.2024',
#        '18.04.2024', '15.03.2024', '01.10.2024', '22.04.2024',
#        '07.05.2024', '02.04.2024', '18.03.2024', '05.01.2024',
#        '21.01.2024', '29.03.2024', '01.12.2023', '30.03.2024',
#        '17.05.2023', '27.03.2024', '21.03.2024', '23.03.2024',
#        '28.03.2024', '05.03.2024', '28.06.2024', '01.09.2024',
#        '02.03.2024', '16.04.2024', '30.07.2024', '13.03.2024',
#        '21.02.2024', '13.11.2023', '09.10.2023', '31.08.2024',
#        '31.10.2024', '06.03.2024', '02.02.2024', '12.02.2024',
#        '10.03.2024', '31.03.2023', '31.12.2023', '20.02.2024',
#        '27.11.2023', '23.02.2024', '01.12.2024', '16.02.2024',
#        '03.02.2024', '09.05.2023', '21.08.2023', '31.12.2025',
#        '19.02.2024', '15.01.2024', '22.11.2023', '16.01.2024',
#        '03.03.2024', '31.10.2023', '04.12.2023', '26.01.2024',
#        '12.11.2023', '31.03.2025', '30.09.2023', '03.01.2024',
#        '31.07.2023', '30.12.2025', '01.12.2025', '18.07.2023',
#        '06.09.2023', '09.09.2024', '12.01.2024', '28.11.2023',
#        '30.09.2024', '09.03.2024', '09.02.2024', '30.04.2026',
#        '27.12.2023', '18.11.2023', '17.01.2024', '20.12.2023',
#        '11.12.2023', '30.08.2023', '16.11.2023', '24.01.2024',
#        '30.06.2023', '01.10.2023', '01.04.2026', '07.07.2023',
#        '23.03.2023', 'Marzec 2024', '01.05.2023', '04.05.2023',
#        '19.06.2023', '01.03.2025', '28.04.2024', '23.08.2023',
#        '30.12.2023', '01.01.2025', '15.11.2023', '27.10.2023',
#        '22.08.2023', '23.11.2023', '05.12.2023', '27.06.2025',
#        '10.05.2023', '08.02.2024', '18.09.2023', '02.10.2023',
#        '26.10.2023', '02.09.2024', 'Kwiecień 2024', '15.01.2023',
#        '01.10.2022', '11.09.2024', '29.11.2023', '24.10.2023',
#        '18.10.2023', '02.01.2024', '17.11.2023', '25.01.2024',
#        '24.06.2025', '11.01.2024', '15.09.2023', '07.01.2024',
#        '25.08.2023', '18.06.2025', '02.10.2024', '25.10.2023',
#        '01.02.2025', '23.09.2022', '22.09.2023', '25.07.2023',
#        '06.05.2024', '20.11.2023', '31.08.2023', '18.12.2023',
#        '17.04.2024', '19.09.2023', '10.10.2023', '15.12.2023',
#        '14.02.2024', '28.08.2023', '06.12.2023', '20.05.2024',
#        '15.05.2024', '10.05.2024', '30.04.2023', '31.07.2024',
#        '05.02.2024', '01.02.2026', '24.02.2024', '13.12.2023',
#        '29.09.2023', '01.06.2025', '28.02.2026', '20.03.2024',
#        '30.08.2024', '23.10.2023', '05.11.2023', '13.09.2023',
#        '13.01.2024', '25.02.2024', '17.10.2024', '01.11.2023',
#        '22.04.2023', '28.04.2023', '22.06.2023', '07.12.2023',
#        '02.11.2023', '12.09.2023', '24.07.2023', '10.07.2023',
#        '20.09.2024', '11.09.2023', '01.04.2023', '21.11.2023',
#        '30.01.2023', '03.08.2023', '30.05.2025', '01.12.2022',
#        '08.11.2023', '13.08.2023', '24.08.2023', '01.03.2023',
#        '18.05.2023', 'Maj 2024', '07.04.2023', '21.12.2023', '07.11.2023',
#        '05.10.2023', '20.02.2023', '26.04.2023', '07.02.2023',
#        '11.08.2023', '10.11.2023', '15.03.2023', '01.04.2025',
#        '11.06.2023', '09.02.2023', '09.11.2023'], dtype=object)

# %%
sell_data[sell_data['Liczba poziomów mieszkania']==5]
# Out:
#                                                   Nazwa        Cena    Miasto  \
# 146   Sprzedam słoneczne 3 pokojowe mieszkanie, z ga...  700 000 zł  Gdańsk,
# 4582                      Mieszkanie inne niż wszystkie  538 654 zł  Gdynia,
#
#                            Dzielnica       Pokoje Pow. całkowita Piętro  \
# 146   Orunia Górna-Gdańsk Południe,    • 3 pokoje       57,46 m²    3/4
# 4582                       Dąbrowa,    • 2 pokoje       42,32 m²    3/5
#
#       Liczba pięter  Liczba sypialni Balkon      Rynek Rodzaj umowy  \
# 146             4.0              NaN    Tak     Wtórny          NaN
# 4582            5.0              NaN    Tak  Pierwotny          NaN
#
#       Rok budowy Data dodania Aktualizacja    Numer ogłoszenia Liczba odsłon  \
# 146       2018.0   14.03.2024   15.04.2024  morizon-1538440364           627
# 4582      2025.0   25.02.2024   25.03.2024          morizon-64            36
#
#       Liczba Punktów Podbić  Liczba poziomów mieszkania  Dostępne od  \
# 146                      25                         5.0  Lipiec 2024
# 4582                      0                         5.0   30.06.2025
#
#      Typ budynku Materiał budowlany Ogrzewanie Inwestycja Stan nieruchomości  \
# 146         Blok                NaN   Miejskie        NaN       Bardzo dobry
# 4582        Blok       Zróżnicowany   Miejskie        NaN       Bardzo dobry
#
#      Typ kuchni  Liczba łazienek łazienka razem z WC Taras Pow. ogródka  \
# 146       Aneks              NaN                 Tak   Nie          NaN
# 4582      Aneks              1.0                 Tak   NaN          NaN
#
#      Forma własności Stolarka okienna Pow. tarasu Pow. loggii Pow. balkonu  \
# 146         Własność              NaN         NaN         NaN          NaN
# 4582        Własność              NaN         NaN         NaN      5,33 m²
#
#         Stan budynku Wysokość wnętrza Pow. łazienki Pow. użytkowa  \
# 146              NaN              NaN           NaN           NaN
# 4582  Do wykończenia           260 cm       4,62 m²           NaN
#
#      Dodatkowe koszty Cena do negocjacji Typ nieruchomości Typ domu  \
# 146               NaN                Tak               NaN      NaN
# 4582              NaN                NaN               NaN      NaN
#
#      Lokalizacja garażu Pow. działki Kominek Urządzony ogród
# 146                 NaN          NaN     NaN             NaN
# 4582                NaN          NaN     NaN             NaN

# %%
sell_data["Cena"].str[-3:].unique()
# Out:
# array([' zł', 'ano', '0 €', 'USD'], dtype=object)

# %%
sell_data.loc[sell_data["Cena"].str[-1] == "€", ["Cena"]] = pd.to_numeric(sell_data[sell_data["Cena"].str[-1] == "€"]["Cena"].str.replace("€","").str.replace(" ", ""))*4.3
sell_data.loc[sell_data["Cena"].str[-3:] == "USD", ["Cena"]] = pd.to_numeric(sell_data[sell_data["Cena"].str[-3:] == "USD"]["Cena"].str.replace("USD","").str.replace(" ", ""))*4

# %%
sell_data = sell_data.drop(sell_data[sell_data["Cena"]=="Zarezerwowano"].index)
sell_data["Cena"] = sell_data["Cena"].astype(str).str.replace("zł","").str.replace(" ", "")
sell_data["Cena"] = pd.to_numeric(sell_data["Cena"])

# %%
sell_data["Miasto"] = sell_data["Miasto"].str.replace(",","")

# %%
sell_data["Pokoje"] = sell_data["Pokoje"].str.replace("• ","")
sell_data["Pokoje"] = sell_data["Pokoje"].str.replace(" pokoje","")
sell_data["Pokoje"] = sell_data["Pokoje"].str.replace(" pokoi","")

# %%
sell_data["Pokoje"] = sell_data["Pokoje"].str.replace(" pokoi","")

# %%
sell_data["Pow. całkowita"] = sell_data["Pow. całkowita"].str[:-3]
sell_data["Pow. całkowita"] = sell_data["Pow. całkowita"].str.replace(",",".")
sell_data["Pow. całkowita"] = pd.to_numeric(sell_data["Pow. całkowita"])

# %%
sell_data['Piętro'] = sell_data['Piętro'].fillna(sell_data['Piętro'].value_counts().index[0])
sell_data["Piętro"] = sell_data["Piętro"].str.split("/")
sell_data["Liczba pięter"] = sell_data["Piętro"].str[1]
sell_data["Piętro"] = sell_data["Piętro"].str[0]

# %%
sell_data
# Out:
#                                                   Nazwa       Cena   Miasto  \
# 0      Luksusowe mieszkanie/3 pokoje/Zajezdnia Wrzeszcz  1399000.0  Gdańsk
# 1                  Mieszkanie 2 pokoje Gdańsk Przymorze   539000.0  Gdańsk
# 2     Mieszkanie ENERGOOSZCZĘDNE 90m² z ogrodem, bez...   360185.0  Gdańsk
# 3                                    Opis nieruchomości   457835.0  Gdańsk
# 4     8700/m2 1,5km tramwaj_ Hale_ komórki_ balkon_R...   580000.0  Gdańsk
# ...                                                 ...        ...      ...
# 5144          Apartament z dużym ogrodem w sercu Sopotu  2337500.0   Sopot
# 5145   Inwestycyjne 3 mieszkania w jednym Sopot koło UG  1649000.0   Sopot
# 5146                             Dwa apaartamenty Sopot  2290000.0   Sopot
# 5147            Sopot Dolny, Sopot Górny, Sopot Wyścigi  1500000.0   Sopot
# 5148                                 Mieszkanie - Sopot  1880000.0   Sopot
#
#                 Dzielnica Pokoje  Pow. całkowita Piętro Liczba pięter  \
# 0        Wrzeszcz Dolny,       3           61.21      1             4
# 1             Przymorze,       2           46.00      8            10
# 2             Łostowice,       4           90.00      1             3
# 3             Łostowice,       2           40.66      1             3
# 4                  Jasień      4           59.80      3             4
# ...                   ...    ...             ...    ...           ...
# 5144              Górny,       5          106.25      1             3
# 5145     Artura Grottgera      5           93.10      2             3
# 5146  Władysława Łokietka      3           74.00      1             3
# 5147              Dolny,       3           80.00      1             3
# 5148              Dolny,       3           81.00      1             2
#
#       Liczba sypialni Balkon      Rynek   Rodzaj umowy  Rok budowy  \
# 0                 2.0    Tak     Wtórny  Na wyłączność      2021.0
# 1                 NaN    Tak     Wtórny  Na wyłączność      1973.0
# 2                 NaN    NaN  Pierwotny            NaN      2025.0
# 3                 NaN    NaN  Pierwotny            NaN      2025.0
# 4                 NaN    Tak  Pierwotny            NaN      2023.0
# ...               ...    ...        ...            ...         ...
# 5144              4.0    NaN  Pierwotny            NaN      2023.0
# 5145              NaN    Tak     Wtórny  Na wyłączność      1950.0
# 5146              NaN    NaN     Wtórny            NaN         NaN
# 5147              NaN    Tak     Wtórny            NaN      1900.0
# 5148              NaN    Nie     Wtórny            NaN      1910.0
#
#      Data dodania Aktualizacja    Numer ogłoszenia Liczba odsłon  \
# 0      22.04.2024   22.04.2024      morizon-467068             1
# 1      03.04.2024   18.04.2024    morizon-WH105140         1 188
# 2      21.03.2024   17.04.2024  morizon-Mieszkanie         3 273
# 3      19.02.2024   22.04.2024    morizon-B2-B2.34            75
# 4      06.03.2024   15.04.2024        morizon-1042           183
# ...           ...          ...                 ...           ...
# 5144   07.08.2023   30.11.2023    morizon-TC550387           307
# 5145   12.01.2022   14.05.2023      morizon-980811         2 657
# 5146   09.11.2023   04.02.2024    morizon-DJ495680           186
# 5147   01.12.2023   16.04.2024      morizon-SE0000           610
# 5148   21.11.2023   02.02.2024      morizon-HL0813           238
#
#       Liczba Punktów Podbić  Liczba poziomów mieszkania Dostępne od  \
# 0                        25                         NaN         NaN
# 1                       301                         1.0  05.04.2024
# 2                       250                         2.0         NaN
# 3                       211                         NaN         NaN
# 4                       210                         NaN         NaN
# ...                     ...                         ...         ...
# 5144                      0                         1.0         NaN
# 5145                      0                         NaN         NaN
# 5146                      0                         1.0  09.11.2023
# 5147                      0                         1.0         NaN
# 5148                      0                         1.0         NaN
#
#             Typ budynku Materiał budowlany   Ogrzewanie           Inwestycja  \
# 0                   NaN                NaN          NaN                  NaN
# 1              Falowiec              Cegła  Co Miejskie                  NaN
# 2     Dom wielorodzinny             Pustak          NaN  Domm 90M2 Z Ogrodem
# 3                   NaN                NaN          NaN              Quercus
# 4                  Blok       Wielka płyta     Miejskie                  NaN
# ...                 ...                ...          ...                  ...
# 5144    Apartamentowiec            Silikat  Co Miejskie                  NaN
# 5145                NaN                NaN          NaN                  NaN
# 5146    Apartamentowiec             Pustak  Co Miejskie                  NaN
# 5147          Kamienica              Cegła          NaN                  NaN
# 5148          Kamienica                NaN       Gazowe                  NaN
#
#      Stan nieruchomości Typ kuchni  Liczba łazienek łazienka razem z WC Taras  \
# 0                   NaN        NaN              NaN                 NaN   NaN
# 1                   NaN        NaN              NaN                 NaN   NaN
# 2        Do wykończenia      Aneks              2.0                 Tak   Tak
# 3                   NaN        NaN              NaN                 NaN   NaN
# 4        Do wykończenia        NaN              NaN                 NaN   NaN
# ...                 ...        ...              ...                 ...   ...
# 5144                NaN        NaN              NaN                 NaN   NaN
# 5145                NaN        NaN              NaN                 NaN   NaN
# 5146                NaN        NaN              NaN                 NaN   Tak
# 5147                NaN    Otwarta              1.0                 Nie   Tak
# 5148       Bardzo dobry     Osobna              1.0                 Nie   Nie
#
#      Pow. ogródka Forma własności Stolarka okienna Pow. tarasu Pow. loggii  \
# 0             NaN             NaN              NaN         NaN         NaN
# 1             NaN             NaN              NaN         NaN         NaN
# 2          200 m²        Własność              NaN         NaN         NaN
# 3             NaN             NaN              NaN         NaN         NaN
# 4             NaN        Własność              PCV         NaN         NaN
# ...           ...             ...              ...         ...         ...
# 5144          NaN             NaN              NaN         NaN         NaN
# 5145          NaN             NaN              NaN         NaN         NaN
# 5146          NaN             NaN              NaN         NaN         NaN
# 5147       100 m²        Własność              NaN       10 m²        4 m²
# 5148          NaN        Własność              NaN         NaN         NaN
#
#      Pow. balkonu  Stan budynku Wysokość wnętrza Pow. łazienki Pow. użytkowa  \
# 0             NaN           NaN              NaN           NaN           NaN
# 1             NaN           NaN              NaN           NaN           NaN
# 2             NaN           NaN              NaN           NaN           NaN
# 3             NaN           NaN              NaN           NaN           NaN
# 4             NaN           NaN              NaN           NaN           NaN
# ...           ...           ...              ...           ...           ...
# 5144          NaN           NaN              NaN           NaN           NaN
# 5145          NaN           NaN              NaN           NaN           NaN
# 5146          NaN           NaN              NaN           NaN           NaN
# 5147         4 m²  Bardzo dobry           300 cm          4 m²           NaN
# 5148          NaN  Bardzo dobry              NaN           NaN           NaN
#
#      Dodatkowe koszty Cena do negocjacji Typ nieruchomości Typ domu  \
# 0                 NaN                NaN               NaN      NaN
# 1                 NaN                NaN               NaN      NaN
# 2                 NaN                NaN               NaN      NaN
# 3                 NaN                NaN               NaN      NaN
# 4                 NaN                NaN               NaN      NaN
# ...               ...                ...               ...      ...
# 5144              NaN                NaN               NaN      NaN
# 5145              NaN                NaN               NaN      NaN
# 5146              NaN                NaN               NaN      NaN
# 5147              NaN                Tak               NaN      NaN
# 5148              NaN                Tak               NaN      NaN
#
#      Lokalizacja garażu Pow. działki Kominek Urządzony ogród
# 0                   NaN          NaN     NaN             NaN
# 1                   NaN          NaN     NaN             NaN
# 2                   NaN          NaN     NaN             NaN
# 3                   NaN          NaN     NaN             NaN
# 4                   NaN          NaN     NaN             NaN
# ...                 ...          ...     ...             ...
# 5144                NaN          NaN     NaN             NaN
# 5145                NaN          NaN     NaN             NaN
# 5146                NaN          NaN     NaN             NaN
# 5147                NaN          NaN     NaN             NaN
# 5148                NaN          NaN     NaN             NaN
#
# [5115 rows x 47 columns]
