# %%
import pandas as pd

# %%
gdansk = pd.read_csv(r"data\flat-sell_Gdansk.csv", sep='|')
gdynia = pd.read_csv(r"data\flat-sell_Gdynia.csv", sep='|')
sopot = pd.read_csv(r"data\flat-sell_Sopot.csv", sep='|')

# %%
gdansk.head()
# Out:
#                                             Nazwa          Cena    Miasto  \
# 0                   Nowa Cena *Prawdziwe zdjęcia*  1 179 000 zł  Gdańsk,
# 1            Jelitkowo z widokiem na Park Reagana  2 910 000 zł  Gdańsk,
# 2  klimatyczne 3 pokoje z balkonem przy Ołowiance  1 386 000 zł  Gdańsk,
# 3                  2 pokoje Jaśkowa Dolina Cordia    999 000 zł  Gdańsk,
# 4            Mieszkanie 2 pokoje Gdańsk Przymorze    539 000 zł  Gdańsk,
#
#      Dzielnica Pow. całkowita Piętro  Liczba pięter  Liczba sypialni   Rynek  \
# 0    Letnica,        65,50 m²  13/17           17.0              2.0  Wtórny
# 1  Jelitkowo,        75,50 m²    2/3            3.0              NaN  Wtórny
# 2  Śródmieście          77 m²    1/3            3.0              2.0  Wtórny
# 3   Wrzeszcz,        55,50 m²    2/3            3.0              1.0  Wtórny
# 4  Przymorze,           46 m²   8/10           10.0              NaN  Wtórny
#
#    Rok budowy  ... Wysokość wnętrza Pow. łazienki Stolarka okienna  \
# 0      2021.0  ...              NaN           NaN              NaN
# 1      2010.0  ...              NaN           NaN              NaN
# 2      1921.0  ...              NaN           NaN              NaN
# 3      2023.0  ...              NaN           NaN              NaN
# 4      1973.0  ...              NaN           NaN              NaN
#
#   Pow. balkonu Dodatkowe koszty  Cena do negocjacji Typ nieruchomości  \
# 0          NaN              NaN                 NaN               NaN
# 1          NaN              NaN                 NaN               NaN
# 2          NaN              NaN                 NaN               NaN
# 3          NaN              NaN                 NaN               NaN
# 4          NaN              NaN                 NaN               NaN
#
#    Typ domu Pow. działki Lokalizacja garażu
# 0       NaN          NaN                NaN
# 1       NaN          NaN                NaN
# 2       NaN          NaN                NaN
# 3       NaN          NaN                NaN
# 4       NaN          NaN                NaN
#
# [5 rows x 44 columns]

# %%
sell_data = pd.concat([gdansk, gdynia, sopot])

# %%
sell_data.tail()
# Out:
#                                                 Nazwa          Cena   Miasto  \
# 309           Na sprzedaż 3 pokojowe mieszkanie Sopot    650 000 zł  Sopot,
# 310  Inwestycyjne 3 mieszkania w jednym Sopot koło UG  1 649 000 zł  Sopot,
# 311                            Dwa apaartamenty Sopot  2 290 000 zł  Sopot,
# 312           Sopot Dolny, Sopot Górny, Sopot Wyścigi  1 500 000 zł  Sopot,
# 313                                Mieszkanie - Sopot  1 880 000 zł  Sopot,
#
#                Dzielnica Pow. całkowita Piętro  Liczba pięter  \
# 309          Przylesie,        46,16 m²  10/10           10.0
# 310     Artura Grottgera       93,10 m²    2/3            3.0
# 311  Władysława Łokietka          74 m²    NaN            3.0
# 312              Dolny,           80 m²    NaN            1.0
# 313              Dolny,           81 m²    1/2            2.0
#
#      Liczba sypialni   Rynek  Rok budowy  ... Pow. łazienki Stolarka okienna  \
# 309              NaN  Wtórny         NaN  ...           NaN              NaN
# 310              NaN  Wtórny      1950.0  ...           NaN              NaN
# 311              NaN  Wtórny         NaN  ...           NaN              NaN
# 312              NaN  Wtórny      1900.0  ...          4 m²              NaN
# 313              NaN  Wtórny      1910.0  ...           NaN              NaN
#
#     Pow. balkonu Dodatkowe koszty Cena do negocjacji  Typ nieruchomości  \
# 309          NaN              NaN                NaN                NaN
# 310          NaN              NaN                NaN                NaN
# 311          NaN              NaN                NaN                NaN
# 312         4 m²              NaN                Tak                NaN
# 313          NaN              NaN                Tak                NaN
#
#     Typ domu  Pow. działki Lokalizacja garażu Kominek
# 309      NaN           NaN                NaN     NaN
# 310      NaN           NaN                NaN     NaN
# 311      NaN           NaN                NaN     NaN
# 312      NaN           NaN                NaN     NaN
# 313      NaN           NaN                NaN     NaN
#
# [5 rows x 45 columns]

# %%
sell_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4971 entries, 0 to 313
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nazwa                       4971 non-null   object
#  1   Cena                        4971 non-null   object
#  2   Miasto                      4971 non-null   object
#  3   Dzielnica                   4917 non-null   object
#  4   Pow. całkowita              4971 non-null   object
#  5   Piętro                      3637 non-null   object
#  6   Liczba pięter               4609 non-null   float64
#  7   Liczba sypialni             1745 non-null   float64
#  8   Rynek                       4971 non-null   object
#  9   Rok budowy                  4386 non-null   float64
#  10  Ogrzewanie                  3273 non-null   object
#  11  Data dodania                4971 non-null   object
#  12  Aktualizacja                4971 non-null   object
#  13  Numer ogłoszenia            4971 non-null   object
#  14  Liczba odsłon               4971 non-null   object
#  15  Liczba Punktów Podbić       4971 non-null   int64
#  16  Pow. użytkowa               228 non-null    object
#  17  Liczba poziomów mieszkania  1002 non-null   float64
#  18  Balkon                      2610 non-null   object
#  19  Typ budynku                 3359 non-null   object
#  20  Materiał budowlany          1687 non-null   object
#  21  Rodzaj umowy                1438 non-null   object
#  22  Dostępne od                 1117 non-null   object
#  23  Inwestycja                  541 non-null    object
#  24  Stan nieruchomości          693 non-null    object
#  25  Typ kuchni                  762 non-null    object
#  26  Liczba łazienek             602 non-null    float64
#  27  łazienka razem z WC         312 non-null    object
#  28  Taras                       1140 non-null   object
#  29  Pow. ogródka                27 non-null     object
#  30  Forma własności             794 non-null    object
#  31  Pow. tarasu                 52 non-null     object
#  32  Pow. loggii                 35 non-null     object
#  33  Stan budynku                309 non-null    object
#  34  Wysokość wnętrza            226 non-null    object
#  35  Pow. łazienki               91 non-null     object
#  36  Stolarka okienna            119 non-null    object
#  37  Pow. balkonu                163 non-null    object
#  38  Dodatkowe koszty            39 non-null     object
#  39  Cena do negocjacji          64 non-null     object
#  40  Typ nieruchomości           18 non-null     object
#  41  Typ domu                    7 non-null      object
#  42  Pow. działki                1 non-null      object
#  43  Lokalizacja garażu          2 non-null      object
#  44  Kominek                     1 non-null      object
# dtypes: float64(5), int64(1), object(39)
# memory usage: 1.7+ MB
