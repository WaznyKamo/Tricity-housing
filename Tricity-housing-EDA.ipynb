# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
gdansk = pd.read_csv(r"data\flat-sell_Gdansk.csv", sep='|')
gdynia = pd.read_csv(r"data\flat-sell_Gdynia.csv", sep='|')
sopot = pd.read_csv(r"data\flat-sell_Sopot.csv", sep='|')

# %%
gdansk.head()
# Out:
#                                                Nazwa          Cena    Miasto  \
# 0   Luksusowe mieszkanie/3 pokoje/Zajezdnia Wrzeszcz  1 399 000 zł  Gdańsk,
# 1               Mieszkanie 2 pokoje Gdańsk Przymorze    539 000 zł  Gdańsk,
# 2  Mieszkanie ENERGOOSZCZĘDNE 90m² z ogrodem, bez...    360 185 zł  Gdańsk,
# 3                                 Opis nieruchomości    457 835 zł  Gdańsk,
# 4  8700/m2 1,5km tramwaj_ Hale_ komórki_ balkon_R...    580 000 zł  Gdańsk,
#
#           Dzielnica       Pokoje Pow. całkowita Piętro  Liczba pięter  \
# 0  Wrzeszcz Dolny,    • 3 pokoje       61,21 m²    1/4            4.0
# 1       Przymorze,    • 2 pokoje          46 m²   8/10           10.0
# 2       Łostowice,    • 4 pokoje          90 m²    NaN            NaN
# 3       Łostowice,    • 2 pokoje       40,66 m²    NaN            NaN
# 4            Jasień   • 4 pokoje       59,80 m²    3/4            4.0
#
#    Liczba sypialni Balkon      Rynek   Rodzaj umowy  Rok budowy Data dodania  \
# 0              2.0    Tak     Wtórny  Na wyłączność      2021.0   22.04.2024
# 1              NaN    Tak     Wtórny  Na wyłączność      1973.0   03.04.2024
# 2              NaN    NaN  Pierwotny            NaN      2025.0   21.03.2024
# 3              NaN    NaN  Pierwotny            NaN      2025.0   19.02.2024
# 4              NaN    Tak  Pierwotny            NaN      2023.0   06.03.2024
#
#   Aktualizacja    Numer ogłoszenia Liczba odsłon  Liczba Punktów Podbić  \
# 0   22.04.2024      morizon-467068             1                     25
# 1   18.04.2024    morizon-WH105140         1 188                    301
# 2   17.04.2024  morizon-Mieszkanie         3 273                    250
# 3   22.04.2024    morizon-B2-B2.34            75                    211
# 4   15.04.2024        morizon-1042           183                    210
#
#    Liczba poziomów mieszkania Dostępne od        Typ budynku  \
# 0                         NaN         NaN                NaN
# 1                         1.0  05.04.2024           Falowiec
# 2                         2.0         NaN  Dom wielorodzinny
# 3                         NaN         NaN                NaN
# 4                         NaN         NaN               Blok
#
#   Materiał budowlany   Ogrzewanie           Inwestycja Stan nieruchomości  \
# 0                NaN          NaN                  NaN                NaN
# 1              Cegła  Co Miejskie                  NaN                NaN
# 2             Pustak          NaN  Domm 90M2 Z Ogrodem     Do wykończenia
# 3                NaN          NaN              Quercus                NaN
# 4       Wielka płyta     Miejskie                  NaN     Do wykończenia
#
#   Typ kuchni  Liczba łazienek łazienka razem z WC Taras Pow. ogródka  \
# 0        NaN              NaN                 NaN   NaN          NaN
# 1        NaN              NaN                 NaN   NaN          NaN
# 2      Aneks              2.0                 Tak   Tak       200 m²
# 3        NaN              NaN                 NaN   NaN          NaN
# 4        NaN              NaN                 NaN   NaN          NaN
#
#   Forma własności Stolarka okienna Pow. tarasu Pow. loggii Pow. balkonu  \
# 0             NaN              NaN         NaN         NaN          NaN
# 1             NaN              NaN         NaN         NaN          NaN
# 2        Własność              NaN         NaN         NaN          NaN
# 3             NaN              NaN         NaN         NaN          NaN
# 4        Własność              PCV         NaN         NaN          NaN
#
#   Stan budynku Wysokość wnętrza Pow. łazienki Pow. użytkowa  Dodatkowe koszty  \
# 0          NaN              NaN           NaN           NaN               NaN
# 1          NaN              NaN           NaN           NaN               NaN
# 2          NaN              NaN           NaN           NaN               NaN
# 3          NaN              NaN           NaN           NaN               NaN
# 4          NaN              NaN           NaN           NaN               NaN
#
#   Cena do negocjacji Typ nieruchomości Typ domu Lokalizacja garażu  \
# 0                NaN               NaN      NaN                NaN
# 1                NaN               NaN      NaN                NaN
# 2                NaN               NaN      NaN                NaN
# 3                NaN               NaN      NaN                NaN
# 4                NaN               NaN      NaN                NaN
#
#   Pow. działki
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
sell_data = pd.concat([gdansk, gdynia, sopot])

# %%
sell_data.tail()
# Out:
#                                                 Nazwa          Cena   Miasto  \
# 365         Apartament z dużym ogrodem w sercu Sopotu  2 337 500 zł  Sopot,
# 366  Inwestycyjne 3 mieszkania w jednym Sopot koło UG  1 649 000 zł  Sopot,
# 367                            Dwa apaartamenty Sopot  2 290 000 zł  Sopot,
# 368           Sopot Dolny, Sopot Górny, Sopot Wyścigi  1 500 000 zł  Sopot,
# 369                                Mieszkanie - Sopot  1 880 000 zł  Sopot,
#
#                Dzielnica       Pokoje Pow. całkowita Piętro  Liczba pięter  \
# 365              Górny,     • 5 pokoi      106,25 m²    NaN            3.0
# 366     Artura Grottgera    • 5 pokoi       93,10 m²    2/3            3.0
# 367  Władysława Łokietka   • 3 pokoje          74 m²    NaN            3.0
# 368              Dolny,    • 3 pokoje          80 m²    NaN            1.0
# 369              Dolny,    • 3 pokoje          81 m²    1/2            2.0
#
#      Liczba sypialni Balkon      Rynek   Rodzaj umowy  Rok budowy  \
# 365              4.0    NaN  Pierwotny            NaN      2023.0
# 366              NaN    Tak     Wtórny  Na wyłączność      1950.0
# 367              NaN    NaN     Wtórny            NaN         NaN
# 368              NaN    Tak     Wtórny            NaN      1900.0
# 369              NaN    Nie     Wtórny            NaN      1910.0
#
#     Data dodania Aktualizacja  Numer ogłoszenia Liczba odsłon  \
# 365   07.08.2023   30.11.2023  morizon-TC550387           307
# 366   12.01.2022   14.05.2023    morizon-980811         2 657
# 367   09.11.2023   04.02.2024  morizon-DJ495680           186
# 368   01.12.2023   16.04.2024    morizon-SE0000           610
# 369   21.11.2023   02.02.2024    morizon-HL0813           238
#
#      Liczba Punktów Podbić  Liczba poziomów mieszkania Dostępne od  \
# 365                      0                         1.0         NaN
# 366                      0                         NaN         NaN
# 367                      0                         1.0  09.11.2023
# 368                      0                         1.0         NaN
# 369                      0                         1.0         NaN
#
#          Typ budynku Materiał budowlany   Ogrzewanie Inwestycja  \
# 365  Apartamentowiec            Silikat  Co Miejskie        NaN
# 366              NaN                NaN          NaN        NaN
# 367  Apartamentowiec             Pustak  Co Miejskie        NaN
# 368        Kamienica              Cegła          NaN        NaN
# 369        Kamienica                NaN       Gazowe        NaN
#
#     Stan nieruchomości Typ kuchni  Liczba łazienek łazienka razem z WC Taras  \
# 365                NaN        NaN              NaN                 NaN   NaN
# 366                NaN        NaN              NaN                 NaN   NaN
# 367                NaN        NaN              NaN                 NaN   Tak
# 368                NaN    Otwarta              1.0                 Nie   Tak
# 369       Bardzo dobry     Osobna              1.0                 Nie   Nie
#
#     Pow. ogródka Forma własności Stolarka okienna Pow. tarasu Pow. loggii  \
# 365          NaN             NaN              NaN         NaN         NaN
# 366          NaN             NaN              NaN         NaN         NaN
# 367          NaN             NaN              NaN         NaN         NaN
# 368       100 m²        Własność              NaN       10 m²        4 m²
# 369          NaN        Własność              NaN         NaN         NaN
#
#     Pow. balkonu  Stan budynku Wysokość wnętrza Pow. łazienki Pow. użytkowa  \
# 365          NaN           NaN              NaN           NaN           NaN
# 366          NaN           NaN              NaN           NaN           NaN
# 367          NaN           NaN              NaN           NaN           NaN
# 368         4 m²  Bardzo dobry           300 cm          4 m²           NaN
# 369          NaN  Bardzo dobry              NaN           NaN           NaN
#
#     Dodatkowe koszty Cena do negocjacji Typ nieruchomości Typ domu  \
# 365              NaN                NaN               NaN      NaN
# 366              NaN                NaN               NaN      NaN
# 367              NaN                NaN               NaN      NaN
# 368              NaN                Tak               NaN      NaN
# 369              NaN                Tak               NaN      NaN
#
#     Lokalizacja garażu Pow. działki Kominek Urządzony ogród
# 365                NaN          NaN     NaN             NaN
# 366                NaN          NaN     NaN             NaN
# 367                NaN          NaN     NaN             NaN
# 368                NaN          NaN     NaN             NaN
# 369                NaN          NaN     NaN             NaN

# %%
sell_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5149 entries, 0 to 369
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nazwa                       5149 non-null   object
#  1   Cena                        5149 non-null   object
#  2   Miasto                      5149 non-null   object
#  3   Dzielnica                   5091 non-null   object
#  4   Pokoje                      5149 non-null   object
#  5   Pow. całkowita              5149 non-null   object
#  6   Piętro                      3807 non-null   object
#  7   Liczba pięter               4802 non-null   float64
#  8   Liczba sypialni             1782 non-null   float64
#  9   Balkon                      2680 non-null   object
#  10  Rynek                       5149 non-null   object
#  11  Rodzaj umowy                1490 non-null   object
#  12  Rok budowy                  4565 non-null   float64
#  13  Data dodania                5149 non-null   object
#  14  Aktualizacja                5149 non-null   object
#  15  Numer ogłoszenia            5149 non-null   object
#  16  Liczba odsłon               5149 non-null   object
#  17  Liczba Punktów Podbić       5149 non-null   int64
#  18  Liczba poziomów mieszkania  1018 non-null   float64
#  19  Dostępne od                 1108 non-null   object
#  20  Typ budynku                 3455 non-null   object
#  21  Materiał budowlany          1732 non-null   object
#  22  Ogrzewanie                  3373 non-null   object
#  23  Inwestycja                  618 non-null    object
#  24  Stan nieruchomości          709 non-null    object
#  25  Typ kuchni                  792 non-null    object
#  26  Liczba łazienek             618 non-null    float64
#  27  łazienka razem z WC         307 non-null    object
#  28  Taras                       1181 non-null   object
#  29  Pow. ogródka                29 non-null     object
#  30  Forma własności             795 non-null    object
#  31  Stolarka okienna            105 non-null    object
#  32  Pow. tarasu                 38 non-null     object
#  33  Pow. loggii                 33 non-null     object
#  34  Pow. balkonu                148 non-null    object
#  35  Stan budynku                314 non-null    object
#  36  Wysokość wnętrza            237 non-null    object
#  37  Pow. łazienki               78 non-null     object
#  38  Pow. użytkowa               231 non-null    object
#  39  Dodatkowe koszty            38 non-null     object
#  40  Cena do negocjacji          55 non-null     object
#  41  Typ nieruchomości           17 non-null     object
#  42  Typ domu                    8 non-null      object
#  43  Lokalizacja garażu          2 non-null      object
#  44  Pow. działki                1 non-null      object
#  45  Kominek                     1 non-null      object
#  46  Urządzony ogród             1 non-null      object
# dtypes: float64(5), int64(1), object(41)
# memory usage: 1.9+ MB

# %%
sell_data['Dzielnica'].unique()
# Out:
# array(['Letnica, ', 'Jelitkowo, ', 'Śródmieście', 'Wrzeszcz, ',
#        'Przymorze, ', 'Śródmieście, ', 'Łostowice, ', 'Stogi, ',
#        'Kiełpinek, ', 'Gdańsk, ', 'Morena, ', 'Aniołki, ', 'Oliwa, ',
#        'Żabianka, ', 'Ujeścisko, ', 'Stare Miasto, ', 'Siedlce, ',
#        'Potokowa', 'Zakoniczyn, ', 'Jasień, ', 'Lęborska 22',
#        'Piecki-Migowo, ', 'Chełm, ', 'Kokoszki, ', 'Siedlce', 'Zaspa, ',
#        'Orunia Górna, ', 'Orunia Południe, ', 'Oliwa', 'Wrzeszcz',
#        'Straganiarska', 'Sobieszewo, ', 'Dolne Miasto, ', 'Jelitkowo',
#        'Brzeźno, ', 'Gdańsk', 'Nieborowska', 'Ujeścisko-Łostowice, ',
#        'Orunia Górna-Gdańsk Południe, ', 'Piecki-Migowo', 'Toruńska',
#        'Władysława Cieszyńskiego', 'Osowa, ', 'Karczemki, ', nan,
#        'Barniewice, ', 'Rudniki, ', 'Wyspa Sobieszewska, ', 'Suchanino',
#        'Płocka  14', 'Morena Piecki-Migowo, ', 'Ujeścisko-Łostowice',
#        'Przymorze', 'Orunia, ', 'Brętowo, ', 'Morena', 'Wrzeszcz Górny, ',
#        'Nowy Port, ', 'Orunia Górna', 'Łostowice', 'Niedźwiednik, ',
#        'Suchanino, ', 'Strzyża, ', 'Myśliwska', 'Kazimierza Wielkiego',
#        'Partyzantów', 'Konstantego Bergiela', 'Morena Piecki-Migowo',
#        'Sobieszewo', 'Matarnia, ', 'Czerska', 'Głęboka', 'Przeróbka, ',
#        'Orunia-Św. Wojciech - Lipce, ', 'Wrzeszcz Dolny, ',
#        'Jerzego Świrskiego', 'Maćkowy, ', 'Olszynka', 'Kołobrzeska',
#        'Chełm Południe, ', 'Letnica', 'Żabianka', 'Olszynka, ',
#        'Kokoszki', 'Brzeźno', 'Ferdynanda Magellana', 'Hokejowa',
#        'Jaglana', 'Główne Miasto, ', 'Chełm', 'Sukiennicza', 'Opacka 37',
#        'Kazimierza Pułaskiego', 'Aleja Gen. Józefa Hallera', 'Jasień',
#        'Dolne Miasto', 'Stara Stocznia', 'Kowale, ',
#        'Eugeniusza Węgrzyna', 'Starodworska', 'Stare Przedmieście, ',
#        'Chłopska', 'Ujeścisko - Łostowice', 'Vii Dwór, ', 'Zielona',
#        'Turystyczna', 'Wawelska', 'Perłowa', 'Łąkowa',
#        'Adama Mickiewicza', '3 Brygady Szczerbca', 'Matarnia', 'Legnicka',
#        'Kartuska', 'Starówka', 'Młyniska, ', 'Sandomierska', 'Krzemowa',
#        'Jaśkowa Dolina', 'Jelitkowska', 'Ks. Jerzego Popiełuszki',
#        'Nowy Port', 'Starowiejska', 'Goplańska  49', 'Artura Grottgera',
#        'Angielska Grobla', 'Zagrodowa', 'Przymorze Małe, ', 'Aniołki',
#        'Aleja Pawła Adamowicza', 'Jana Kochanowskiego', 'Niepołomicka',
#        'Budapesztańska', 'Szadółki, ', 'Orunia Górna Gdańsk Południe',
#        'Cygańska Góra', 'Anastazego Wika-Czarnowskiego', 'Olimpijska',
#        'Mostek', 'Wzgórze Mickiewicza, ', 'Osowa', 'Świętokrzyska',
#        'Na Zboczu', 'Polanki', 'Zaspa', 'Orunia-Św. Wojciech-Lipce, ',
#        'Wielkopolska', 'Jabłoniowa', 'Zeusa', 'Kwiatowa',
#        'Ujeścisko Łostowice', 'Szeroka', 'Sienna Grobla', 'Sucha',
#        'Borkowska', 'Orunia-Św. Wojciech-Lipce', 'Zakopiańska',
#        'Chełm I Gdańsk Południe', 'Orunia Południe', 'Długie Ogrody, ',
#        'Damroki', 'Wilhelma Stryjewskiego', 'Stokłosy', 'Migowo, ',
#        'Juliusza Słowackiego', 'Potęgowska', 'Kryształowa',
#        'Powstańców Warszawskich', 'Pastelowa', 'Kadmowa',
#        'Podwale Staromiejskie', 'Sobieszewko, ', 'Orunia Dolna, ',
#        'Władysława Jagiełły', 'Ujeścisko', 'Śniadeckich', 'Jana z Kolna',
#        'Żabianka-Wejhera-Jelitkowo-Tysiąclecia, ', 'Wyzwolenia',
#        'Platynowa', 'Stolema', 'Siennicka', 'Zakoniczyn', 'Ogarna',
#        'Wojciecha Kiedrowskiego', 'Aleja Grunwaldzka', 'Storczykowa',
#        'Nowe Ujeścisko, ', 'Piecki Migowo Morena', 'Grobla III',
#        'Wrzeszcz Górny', 'Chełm Południe', 'Sympatyczna',
#        'Obrońców Westerplatte', 'Stefana Batorego',
#        'Bolesława Krzywoustego', 'Szara',
#        'Ujeścisko Chełm I Gdańsk Południe', 'Leśna Góra',
#        'Prof. Jerzego Stankiewicza', 'Młyniska', 'Cisowa, ',
#        'Chwarzno-Wiczlino, ', 'Pogórze', 'Kamienna Góra, ', 'Chylonia, ',
#        'Redłowo', 'Grabówek, ', 'Wzgórze Św. Maksymiliana, ', 'Redłowo, ',
#        'Mały Kack, ', 'Orłowo, ', 'Działki Leśne, ', 'Oksywie, ',
#        'Leszczynki, ', 'Pogórze, ', 'Wiczlino, ',
#        'Witomino-Leśniczówka, ', 'Pustki Cisowskie, ', 'Zwycięstwa',
#        'Dąbrowa, ', 'Wielki Kack, ', 'Wiczlino', 'Witomino, ',
#        'Kolibki, ', 'Obłuże, ', 'Oksywie', 'Karwiny, ', 'Chwarzno',
#        'Fikakowo, ', 'Witomino-Radiostacja, ', 'Chwarzno-Wiczlino',
#        'Demptowo, ', 'Obłuże', 'Kamienna Góra', 'Gdynia, ', 'Węglowa',
#        'Wielki Kack', 'Mały Kack', 'Dąbrowa', 'Żelazna', 'Kacze Buki, ',
#        'Żołnierzy I Armii Wojska Polskiego', 'Witomino-Leśniczówka',
#        'Chwarzno, ', 'św. Piotra', 'Cisowa', 'Witomino',
#        'Pogórze Górne, ', 'Chylonia', 'Morska',
#        'Wzgórze Św. Maksymiliana', 'Rdestowa',
#        'Pustki Cisowskie   Demptowo, ', '2 Morskiego Pułku Strzelców',
#        'Babie Doły, ', 'Orłowo', 'Pustki Cisowskie-Demptowo', 'Olgierda',
#        'Bernadowo, ', 'Leśna Polana', 'Kosakowo, ', 'Bieszczadzka',
#        'Witomino Radiostacja, ', 'Św. Piotra', 'Żeromskiego Stefana',
#        'Orląt Lwowskich', 'kmdr. Staniewicza', 'Swarzewska',
#        'Działki Leśne', 'Grabówek', 'Karwiny',
#        'Wzgórze Świętego Maksymiliana, ', 'Stefana Żeromskiego',
#        'Dolny, ', 'Tadeusza Kościuszki', 'Dolny Sopot, ', 'Górny, ',
#        'Centrum, ', 'Gen. Kazimierza Pułaskiego', 'Jana Jerzego Haffnera',
#        'Świemirowo, ', 'Sopot, ', 'Karlikowo, ', 'al. Niepodległości',
#        'Ignacego Krasickiego', 'Bohaterów Monte Cassino',
#        'Armii Krajowej', 'Wyścigi, ', 'Gen. Władysława Andersa', 'Smolna',
#        'Władysława Łokietka', 'Józefa Czyżewskiego',
#        'Aleja Niepodległości', 'Podjazd', 'Parkowa', 'Grunwaldzka',
#        '3 Maja', 'Lipowa 10', 'Karlikowo', '1 Maja', 'Dolny',
#        'Mikołaja Reja', 'Górny Sopot, ', 'Mariana Mokwy',
#        'Gen. Władysława Sikorskiego', 'Bitwy Pod Płowcami', '23 Marca',
#        'Króla Jana Kazimierza', 'Niepodległości', 'Dolny Sopot',
#        'Bolesława Chrobrego', 'Górny', 'Marii Skłodowskiej-Curie',
#        'Lipowa', 'Fryderyka Chopina', 'Sopot Górny', 'Stefana Okrzei',
#        'gen. Władysława Sikorskiego', 'Polna', 'Karlikowska',
#        'Przylesie, '], dtype=object)

# %%
sell_data['Piętro'].unique()
# Out:
# array(['13/17', '2/3', '1/3', '8/10', '5/5', nan, '1/8', '3/4', '2/6',
#        '3/3', '1/4', '2/5', '6/17', '1/2', '4/4', '6/6', '1/6', '3/6',
#        '2/17', '7/9', '5/12', '10/10', '14/17', '3/5', '1/1', '5/6',
#        '2/4', '4/6', '7/7', '3/7', '1/10', '3/10', '16/16', '2/10', '2/2',
#        '10/12', '5/17', '11/11', '17/18', '6/10', '7/10', '4/5', '1/5',
#        '15/16', '1/9', '4/10', '9/10', '4/8', '1/17', '8/17', '9/17',
#        '12/17', '15/17', '10/17', '12/16', '4/16', '1/12', '16/17',
#        '7/17', '4/12', '2/12', '4/7', '2/11', '8/8', '1/11', '5/11',
#        '6/11', '3/8', '7/12', '1/7', '2/7', '5/9', '5/7', '2/16', '4/17',
#        '10/16', '6/9', '17/17', '5/16', '9/9', '13/19', '8/9', '13/16',
#        '15/18', '7/8', '7/14', '12/12', '5/10', '10/18', '3/17', '5/8',
#        '4/11', '6/7', '1/13', '6/16', '3/9', '1/18', '8/12', '11/17',
#        '9/11', '12/18', '3/12', '6/12', '18/18', '11/16', '14/16', '1/16',
#        '4/9', '4/18', '6/8', '12/15', '9/16', '10/15', '1/15', '9/12',
#        '7/18', '2/8', '7/13', '5/18', '3/18', '2/18', '7/16', '23/29',
#        '8/16', '21/37', '20/23', '13/23', '23/23', '15/23', '15/29',
#        'Suterena/4', '2/28', '3/11', '10/11', '20/28', '3/13', '15/32',
#        '15/27', '3/14', '6/14', '6/18', '17/32', '27/27', '2/32', '3/16',
#        '14/14', 'Suterena/2', '4/13'], dtype=object)

# %%
sell_data['Liczba łazienek'].unique()
# Out:
# array([nan,  2.,  1.,  4.,  3.,  5.])

# %%
sell_data['Liczba poziomów mieszkania'].unique()
# Out:
# array([nan,  1.,  2.,  4.,  5.,  3.])

# %%
sell_data['Dostępne od'].unique()
# Out:
# array([nan, '05.04.2024', '05.09.2023', '04.03.2024', '30.04.2024',
#        '01.03.2024', '14.03.2024', '01.02.2024', '14.04.2024',
#        '08.04.2024', '01.07.2024', '22.01.2024', '28.02.2024',
#        '31.01.2024', '09.04.2024', '31.03.2024', '02.12.2024',
#        '07.03.2024', '18.01.2024', '10.01.2024', '30.11.2023',
#        '01.04.2024', '27.10.2023', '29.03.2023', '12.03.2024',
#        '29.02.2024', '01.06.2024', '05.03.2024', '24.06.2024',
#        '15.04.2024', '30.06.2024', '13.02.2024', '31.05.2025',
#        '06.03.2024', 'Lipiec 2024', 'Od zaraz', '31.05.2024',
#        'Czerwiec 2024', '04.04.2024', '11.04.2024', '30.12.2024',
#        '27.02.2024', '22.02.2024', '09.01.2024', '08.01.2024',
#        '02.02.2026', '15.01.2026', '26.03.2024', '19.03.2024',
#        '01.08.2023', '02.12.2023', '01.09.2023', '25.03.2024',
#        '15.01.2023', '15.02.2024', '07.02.2024', '30.06.2025',
#        '31.12.2024', '13.04.2023', '28.09.2023', '03.04.2024',
#        '13.03.2024', '23.02.2024', '31.05.2023', '15.07.2023',
#        '11.01.2024', '08.03.2024', '01.05.2023', '01.12.2023',
#        '01.01.2024', '23.11.2023', '31.07.2023', '18.10.2023',
#        '14.12.2023', '07.07.2023', '02.02.2024', '06.04.2024',
#        '20.04.2024', '01.05.2024', '16.03.2024', '01.11.2024',
#        '07.04.2024', '18.03.2024', '22.03.2024', '13.04.2024',
#        '01.08.2024', '27.03.2024', '28.03.2024', '29.01.2024',
#        '11.03.2024', '30.03.2025', '18.04.2024', '10.04.2024',
#        '17.05.2023', '15.07.2024', '27.04.2024', '12.12.2023',
#        '22.12.2023', '15.03.2024', '29.03.2024', '02.04.2024',
#        '07.05.2024', '12.04.2024', '21.01.2024', '30.03.2024',
#        '23.03.2024', '21.03.2024', '28.06.2024', '01.09.2024',
#        '02.03.2024', '09.10.2023', '30.07.2024', '21.02.2024',
#        '03.03.2024', '13.11.2023', '31.10.2024', '10.03.2024',
#        '26.02.2024', '19.12.2023', '31.12.2023', '05.01.2024',
#        '12.02.2024', '16.02.2024', '31.12.2025', '27.11.2023',
#        '30.01.2024', '21.08.2023', '31.03.2023', '15.01.2024',
#        '03.02.2024', '19.04.2023', '09.05.2023', '19.02.2024',
#        '01.12.2025', '01.04.2026', '08.02.2024', '22.11.2023',
#        '27.12.2023', '31.03.2025', '11.12.2023', '20.02.2024',
#        '31.10.2023', '12.01.2024', '14.11.2023', '01.12.2024',
#        '26.01.2024', '17.01.2024', '29.11.2023', '12.11.2023',
#        '30.09.2023', '03.01.2024', '30.12.2025', '09.03.2024',
#        '09.02.2024', '30.09.2024', '01.10.2024', '31.08.2024',
#        '16.01.2024', '20.01.2024', '30.04.2026', '16.12.2024',
#        '20.12.2023', '30.08.2023', '16.11.2023', '24.01.2024',
#        '17.04.2024', '01.10.2023', '04.12.2023', '23.03.2023',
#        '15.11.2023', 'Marzec 2024', '04.05.2023', '19.06.2023',
#        '18.07.2023', '01.03.2025', '28.04.2024', '05.12.2023',
#        '01.01.2025', '23.08.2023', '30.12.2023', '06.01.2024',
#        '29.06.2024', '22.08.2023', '05.02.2024', '09.02.2023',
#        '27.06.2025', '10.05.2023', '09.12.2025', '09.11.2023',
#        '18.09.2023', '02.10.2023', '26.10.2023', '02.09.2024',
#        'Kwiecień 2024', '01.10.2022', '09.09.2024', '11.09.2024',
#        '17.11.2023', '18.11.2023', '24.10.2023', '22.09.2023',
#        '02.01.2024', '07.01.2024', '25.01.2024', '24.06.2025',
#        '06.09.2023', '30.06.2023', '15.09.2023', '25.08.2023',
#        '18.06.2025', '02.10.2024', '25.10.2023', '01.02.2025',
#        '23.09.2022', '25.07.2023', '31.07.2024', '20.11.2023',
#        '31.08.2023', '19.09.2023', '10.10.2023', '15.12.2023',
#        '18.12.2023', '14.02.2024', '28.08.2023', '06.12.2023',
#        '21.11.2023', '06.05.2024', '10.05.2024', '25.02.2024',
#        '30.08.2024', '30.04.2023', '26.04.2024', '01.06.2025',
#        '20.03.2024', '13.12.2023', '29.09.2023', '20.10.2023',
#        '28.02.2026', '13.01.2024', '11.09.2023', '23.10.2023',
#        '19.01.2024', '10.07.2023', '24.02.2024', '05.11.2023',
#        '01.11.2023', '13.09.2023', '24.07.2023', '17.10.2024',
#        '22.04.2023', '28.04.2023', '22.06.2023', '07.12.2023',
#        '12.09.2023', '02.11.2023', '20.09.2024', '28.11.2023',
#        '01.04.2023', '30.01.2023', '03.08.2023', '08.11.2023',
#        '30.05.2025', '01.12.2022', '27.07.2023', '13.08.2023',
#        '24.08.2023', '01.03.2023', '18.05.2023', '07.04.2023',
#        '21.12.2023', '07.11.2023', '05.10.2023', '20.02.2023',
#        '26.04.2023', '07.02.2023', '11.08.2023', '10.11.2023',
#        '15.03.2023', '11.06.2023'], dtype=object)

# %%
sell_data[sell_data['Liczba poziomów mieszkania']==5]
# Out:
#                                                  Nazwa        Cena    Miasto  \
# 160  Sprzedam słoneczne 3 pokojowe mieszkanie, z ga...  730 000 zł  Gdańsk,
# 506        3 pokojowe mieszkanie|Os.Nawigator Eurostyl  549 000 zł  Gdynia,
# 550           Dwupokojowe | Nawigator Eurostyl | 2014r  555 000 zł  Gdynia,
# 882                      Mieszkanie inne niż wszystkie  538 654 zł  Gdynia,
#
#                           Dzielnica Pow. całkowita Piętro  Liczba pięter  \
# 160  Orunia Górna-Gdańsk Południe,        57,46 m²    3/4            4.0
# 506                        Obłuże,        46,50 m²    2/4            4.0
# 550                        Obłuże,        46,50 m²    2/4            4.0
# 882                       Dąbrowa,        42,32 m²    3/5            5.0
#
#      Liczba sypialni      Rynek  Rok budowy   Ogrzewanie Data dodania  \
# 160              NaN     Wtórny      2018.0     Miejskie   14.03.2024
# 506              2.0     Wtórny      2014.0  Co Miejskie   20.03.2024
# 550              1.0     Wtórny      2014.0  Co Miejskie   20.03.2024
# 882              NaN  Pierwotny      2025.0     Miejskie   25.02.2024
#
#     Aktualizacja    Numer ogłoszenia Liczba odsłon  Liczba Punktów Podbić  \
# 160   09.04.2024  morizon-1538440364           494                     25
# 506   25.03.2024    morizon-WH674906           147                      0
# 550   20.03.2024    morizon-WH338173            93                      0
# 882   25.03.2024          morizon-64            31                      0
#
#     Pow. użytkowa  Liczba poziomów mieszkania Balkon      Typ budynku  \
# 160           NaN                         5.0    Tak             Blok
# 506           NaN                         5.0    Tak  Apartamentowiec
# 550           NaN                         5.0    Tak  Apartamentowiec
# 882           NaN                         5.0    Tak             Blok
#
#     Materiał budowlany   Rodzaj umowy  Dostępne od Inwestycja  \
# 160                NaN            NaN  Lipiec 2024        NaN
# 506            Silikat  Na wyłączność   18.03.2024        NaN
# 550            Silikat  Na wyłączność   18.03.2024        NaN
# 882       Zróżnicowany            NaN   30.06.2025        NaN
#
#     Stan nieruchomości Typ kuchni  Liczba łazienek łazienka razem z WC Taras  \
# 160       Bardzo dobry      Aneks              NaN                 Tak   Nie
# 506                NaN        NaN              NaN                 NaN   NaN
# 550                NaN        NaN              NaN                 NaN   NaN
# 882       Bardzo dobry      Aneks              1.0                 Tak   NaN
#
#     Pow. ogródka Forma własności Pow. tarasu Pow. loggii    Stan budynku  \
# 160          NaN        Własność         NaN         NaN             NaN
# 506          NaN             NaN         NaN         NaN             NaN
# 550          NaN             NaN         NaN         NaN             NaN
# 882          NaN        Własność         NaN         NaN  Do wykończenia
#
#     Wysokość wnętrza Pow. łazienki Stolarka okienna Pow. balkonu  \
# 160              NaN           NaN              NaN          NaN
# 506              NaN           NaN              NaN          NaN
# 550              NaN           NaN              NaN          NaN
# 882           260 cm       4,62 m²              NaN      5,33 m²
#
#     Dodatkowe koszty Cena do negocjacji Typ nieruchomości Typ domu  \
# 160              NaN                Tak               NaN      NaN
# 506              NaN                NaN               NaN      NaN
# 550              NaN                NaN               NaN      NaN
# 882              NaN                NaN               NaN      NaN
#
#     Pow. działki Lokalizacja garażu Kominek
# 160          NaN                NaN     NaN
# 506          NaN                NaN     NaN
# 550          NaN                NaN     NaN
# 882          NaN                NaN     NaN
